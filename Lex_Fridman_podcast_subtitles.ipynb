# %% [markdown]
# <a href="https://colab.research.google.com/github/rsidorchuk93/text/blob/main/Lex_Fridman_podcast_subtitles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lex Fridman podcast transcripts analysis

# %% [markdown]
# Transcripts data downloaded from https://karpathy.ai/lexicap/

# %%
# connecting to Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing libraries
import pandas as pd
import os
import re

# %%
folder = "/content/drive/My Drive/text/lex_fridman_vtt/"

# %%
os.listdir(folder)
# Out:
# ['episode_232_small.vtt',
#  'episode_232_large.vtt',
#  'episode_231_small.vtt',
#  'episode_231_large.vtt',
#  'episode_230_large.vtt',
#  'episode_229_small.vtt',
#  'episode_228_small.vtt',
#  'episode_228_large.vtt',
#  'episode_230_small.vtt',
#  'episode_229_large.vtt',
#  'episode_227_small.vtt',
#  'episode_227_large.vtt',
#  'episode_272_small.vtt',
#  'episode_272_large.vtt',
#  'episode_269_small.vtt',
#  'episode_270_large.vtt',
#  'episode_271_small.vtt',
#  'episode_271_large.vtt',
#  'episode_270_small.vtt',
#  'episode_269_large.vtt',
#  'episode_267_small.vtt',
#  'episode_267_large.vtt',
#  'episode_266_small.vtt',
#  'episode_266_large.vtt',
#  'episode_265_small.vtt',
#  'episode_265_large.vtt',
#  'episode_264_large.vtt',
#  'episode_263_large.vtt',
#  'episode_264_small.vtt',
#  'episode_263_small.vtt',
#  'episode_262_small.vtt',
#  'episode_262_large.vtt',
#  'episode_260_small.vtt',
#  'episode_260_large.vtt',
#  'episode_261_small.vtt',
#  'episode_261_large.vtt',
#  'episode_259_small.vtt',
#  'episode_258_small.vtt',
#  'episode_259_large.vtt',
#  'episode_257_small.vtt',
#  'episode_258_large.vtt',
#  'episode_257_large.vtt',
#  'episode_256_large.vtt',
#  'episode_256_small.vtt',
#  'episode_255_small.vtt',
#  'episode_255_large.vtt',
#  'episode_253_large.vtt',
#  'episode_254_small.vtt',
#  'episode_254_large.vtt',
#  'episode_253_small.vtt',
#  'episode_252_small.vtt',
#  'episode_252_large.vtt',
#  'Untitled0.ipynb',
#  'episode_251_small.vtt',
#  'episode_250_large.vtt',
#  'episode_251_large.vtt',
#  'episode_250_small.vtt',
#  'episode_249_small.vtt',
#  'episode_249_large.vtt',
#  'episode_248_large.vtt',
#  'episode_248_small.vtt',
#  'episode_247_small.vtt',
#  'episode_247_large.vtt',
#  'episode_246_small.vtt',
#  'episode_246_large.vtt',
#  'episode_245_small.vtt',
#  'episode_245_large.vtt',
#  'episode_244_small.vtt',
#  'episode_244_large.vtt',
#  'episode_243_large.vtt',
#  'episode_243_small.vtt',
#  'episode_242_small.vtt',
#  'episode_242_large.vtt',
#  'episode_241_large.vtt',
#  'episode_241_small.vtt',
#  'episode_240_small.vtt',
#  'episode_240_large.vtt',
#  'episode_239_large.vtt',
#  'episode_238_small.vtt',
#  'episode_237_small.vtt',
#  'episode_239_small.vtt',
#  'episode_238_large.vtt',
#  'episode_237_large.vtt',
#  'episode_236_small.vtt',
#  'episode_233_large.vtt',
#  'episode_235_small.vtt',
#  'episode_235_large.vtt',
#  'episode_236_large.vtt',
#  'episode_234_small.vtt',
#  'episode_233_small.vtt',
#  'episode_234_large.vtt',
#  'episode_302_large.vtt',
#  'episode_301_small.vtt',
#  'episode_298_small.vtt',
#  'episode_298_large.vtt',
#  'episode_299_large.vtt',
#  'episode_301_large.vtt',
#  'episode_299_small.vtt',
#  'episode_300_large.vtt',
#  'episode_300_small.vtt',
#  'episode_297_small.vtt',
#  'episode_297_large.vtt',
#  'episode_295_small.vtt',
#  'episode_296_large.vtt',
#  'episode_296_small.vtt',
#  'episode_295_large.vtt',
#  'episode_293_small.vtt',
#  'episode_294_small.vtt',
#  'episode_294_large.vtt',
#  'episode_293_large.vtt',
#  'episode_292_small.vtt',
#  'episode_292_large.vtt',
#  'episode_290_small.vtt',
#  'episode_290_large.vtt',
#  'episode_289_small.vtt',
#  'episode_286_large.vtt',
#  'episode_288_large.vtt',
#  'episode_289_large.vtt',
#  'episode_286_small.vtt',
#  'episode_288_small.vtt',
#  'episode_285_small.vtt',
#  'episode_285_large.vtt',
#  'episode_284_small.vtt',
#  'episode_284_large.vtt',
#  'episode_279_large.vtt',
#  'episode_280_large.vtt',
#  'episode_281_large.vtt',
#  'episode_279_small.vtt',
#  'episode_281_small.vtt',
#  'episode_280_small.vtt',
#  'episode_278_small.vtt',
#  'episode_278_large.vtt',
#  'episode_277_large.vtt',
#  'episode_277_small.vtt',
#  'episode_276_small.vtt',
#  'episode_276_large.vtt',
#  'episode_275_small.vtt',
#  'episode_275_large.vtt',
#  'episode_274_small.vtt',
#  'episode_274_large.vtt',
#  'episode_273_small.vtt',
#  'episode_273_large.vtt',
#  'episode_323_small.vtt',
#  'episode_323_large.vtt',
#  'episode_324_large.vtt',
#  'episode_325_large.vtt',
#  'episode_322_small.vtt',
#  'episode_322_large.vtt',
#  'episode_321_small.vtt',
#  'episode_321_large.vtt',
#  'episode_320_small.vtt',
#  'episode_318_small.vtt',
#  'episode_320_large.vtt',
#  'episode_318_large.vtt',
#  'episode_319_small.vtt',
#  'episode_319_large.vtt',
#  'episode_317_small.vtt',
#  'episode_317_large.vtt',
#  'episode_315_large.vtt',
#  'episode_315_small.vtt',
#  'episode_316_large.vtt',
#  'episode_316_small.vtt',
#  'episode_314_small.vtt',
#  'episode_314_large.vtt',
#  'episode_313_small.vtt',
#  'episode_313_large.vtt',
#  'episode_312_small.vtt',
#  'episode_312_large.vtt',
#  'episode_311_large.vtt',
#  'episode_310_small.vtt',
#  'episode_311_small.vtt',
#  'episode_310_large.vtt',
#  'episode_309_large.vtt',
#  'episode_309_small.vtt',
#  'episode_308_large.vtt',
#  'episode_308_small.vtt',
#  'episode_307_small.vtt',
#  'episode_307_large.vtt',
#  'episode_306_small.vtt',
#  'episode_306_large.vtt',
#  'episode_305_small.vtt',
#  'episode_305_large.vtt',
#  'episode_303_small.vtt',
#  'episode_303_large.vtt',
#  'episode_304_small.vtt',
#  'episode_304_large.vtt',
#  'episode_302_small.vtt',
#  'episode_208_small.vtt',
#  'episode_220_large.vtt',
#  'episode_217_large.vtt',
#  'episode_206_large.vtt',
#  'episode_209_small.vtt',
#  'episode_210_large.vtt',
#  'episode_212_small.vtt',
#  'episode_224_small.vtt',
#  'episode_217_small.vtt',
#  'episode_211_large.vtt',
#  'episode_206_small.vtt',
#  'episode_215_large.vtt',
#  'episode_222_large.vtt',
#  'episode_218_small.vtt',
#  'episode_222_small.vtt',
#  'episode_226_large.vtt',
#  'episode_214_small.vtt',
#  'episode_225_large.vtt',
#  'episode_218_large.vtt',
#  'episode_221_large.vtt',
#  'episode_214_large.vtt',
#  'episode_223_large.vtt',
#  'episode_215_small.vtt',
#  'episode_224_large.vtt',
#  'episode_208_large.vtt',
#  'episode_212_large.vtt',
#  'episode_225_small.vtt',
#  'episode_213_large.vtt',
#  'episode_219_small.vtt',
#  'episode_211_small.vtt',
#  'episode_205_large.vtt',
#  'episode_213_small.vtt',
#  'episode_219_large.vtt',
#  'episode_216_large.vtt',
#  'episode_221_small.vtt',
#  'episode_226_small.vtt',
#  'episode_223_small.vtt',
#  'episode_210_small.vtt',
#  'episode_207_large.vtt',
#  'episode_209_large.vtt',
#  'episode_205_small.vtt',
#  'episode_216_small.vtt',
#  'episode_207_small.vtt',
#  'episode_220_small.vtt',
#  'episode_204_large.vtt',
#  'episode_168_large.vtt',
#  'episode_191_small.vtt',
#  'episode_139_small.vtt',
#  'episode_135_large.vtt',
#  'episode_141_small.vtt',
#  'episode_133_large.vtt',
#  'episode_192_small.vtt',
#  'episode_093_large.vtt',
#  'episode_127_small.vtt',
#  'episode_196_large.vtt',
#  'episode_103_small.vtt',
#  'episode_113_small.vtt',
#  'episode_119_small.vtt',
#  'episode_079_large.vtt',
#  'episode_204_small.vtt',
#  'episode_194_large.vtt',
#  'episode_201_small.vtt',
#  'episode_171_small.vtt',
#  'episode_174_small.vtt',
#  'episode_097_large.vtt',
#  'episode_089_small.vtt',
#  'episode_084_large.vtt',
#  'episode_203_small.vtt',
#  'episode_187_large.vtt',
#  'episode_175_large.vtt',
#  'episode_190_large.vtt',
#  'episode_131_small.vtt',
#  'episode_075_large.vtt',
#  'episode_185_small.vtt',
#  'episode_080_small.vtt',
#  'episode_128_large.vtt',
#  'episode_076_large.vtt',
#  'episode_089_large.vtt',
#  'episode_154_large.vtt',
#  'episode_112_large.vtt',
#  'episode_096_small.vtt',
#  'episode_182_large.vtt',
#  'episode_162_small.vtt',
#  'episode_195_small.vtt',
#  'episode_087_large.vtt',
#  'episode_110_large.vtt',
#  'episode_082_small.vtt',
#  'episode_163_small.vtt',
#  'episode_116_large.vtt',
#  'episode_136_small.vtt',
#  'episode_195_large.vtt',
#  'episode_191_large.vtt',
#  'episode_159_large.vtt',
#  'episode_105_large.vtt',
#  'episode_202_large.vtt',
#  'episode_159_small.vtt',
#  'episode_147_large.vtt',
#  'episode_114_large.vtt',
#  'episode_179_large.vtt',
#  'episode_097_small.vtt',
#  'episode_070_large.vtt',
#  'episode_117_small.vtt',
#  'episode_183_large.vtt',
#  'episode_079_small.vtt',
#  'episode_156_small.vtt',
#  'episode_096_large.vtt',
#  'episode_192_large.vtt',
#  'episode_104_small.vtt',
#  'episode_076_small.vtt',
#  'episode_147_small.vtt',
#  'episode_086_small.vtt',
#  'episode_120_large.vtt',
#  'episode_094_small.vtt',
#  'episode_102_large.vtt',
#  'episode_194_small.vtt',
#  'episode_158_large.vtt',
#  'episode_073_small.vtt',
#  'episode_176_small.vtt',
#  'episode_123_small.vtt',
#  'episode_091_large.vtt',
#  'episode_153_small.vtt',
#  'episode_073_large.vtt',
#  'episode_153_large.vtt',
#  'episode_177_small.vtt',
#  'episode_094_large.vtt',
#  'episode_138_large.vtt',
#  'episode_118_large.vtt',
#  'episode_127_large.vtt',
#  'episode_078_small.vtt',
#  'episode_156_large.vtt',
#  'episode_121_small.vtt',
#  'episode_117_large.vtt',
#  'episode_188_large.vtt',
#  'episode_081_small.vtt',
#  'episode_158_small.vtt',
#  'episode_067_large.vtt',
#  'episode_098_large.vtt',
#  'episode_083_small.vtt',
#  'episode_140_large.vtt',
#  'episode_198_large.vtt',
#  'episode_115_small.vtt',
#  'episode_067_small.vtt',
#  'episode_138_small.vtt',
#  'episode_113_large.vtt',
#  'episode_072_small.vtt',
#  'episode_069_large.vtt',
#  'episode_123_large.vtt',
#  'episode_106_small.vtt',
#  'episode_164_small.vtt',
#  'episode_154_small.vtt',
#  'episode_095_large.vtt',
#  'episode_088_small.vtt',
#  'episode_109_small.vtt',
#  'episode_102_small.vtt',
#  'episode_128_small.vtt',
#  'episode_124_large.vtt',
#  'episode_078_large.vtt',
#  'episode_074_large.vtt',
#  'episode_141_large.vtt',
#  'episode_137_large.vtt',
#  'episode_170_large.vtt',
#  'episode_090_large.vtt',
#  'episode_160_large.vtt',
#  'episode_099_small.vtt',
#  'episode_182_small.vtt',
#  'episode_189_small.vtt',
#  'episode_116_small.vtt',
#  'episode_151_large.vtt',
#  'episode_186_large.vtt',
#  'episode_150_large.vtt',
#  'episode_085_large.vtt',
#  'episode_173_small.vtt',
#  'episode_152_large.vtt',
#  'episode_157_small.vtt',
#  'episode_144_small.vtt',
#  'episode_196_small.vtt',
#  'episode_105_small.vtt',
#  'episode_104_large.vtt',
#  'episode_080_large.vtt',
#  'episode_169_small.vtt',
#  'episode_093_small.vtt',
#  'episode_166_large.vtt',
#  'episode_161_large.vtt',
#  'episode_083_large.vtt',
#  'episode_101_large.vtt',
#  'episode_122_large.vtt',
#  'episode_145_small.vtt',
#  'episode_202_small.vtt',
#  'episode_098_small.vtt',
#  'episode_114_small.vtt',
#  'episode_091_small.vtt',
#  'episode_172_small.vtt',
#  'episode_092_small.vtt',
#  'episode_199_large.vtt',
#  'episode_201_large.vtt',
#  'episode_133_small.vtt',
#  'episode_084_small.vtt',
#  'episode_107_large.vtt',
#  'episode_187_small.vtt',
#  'episode_131_large.vtt',
#  'episode_066_large.vtt',
#  'episode_175_small.vtt',
#  'episode_099_large.vtt',
#  'episode_126_large.vtt',
#  'episode_087_small.vtt',
#  'episode_183_small.vtt',
#  'episode_092_large.vtt',
#  'episode_164_large.vtt',
#  'episode_178_small.vtt',
#  'episode_181_small.vtt',
#  'episode_161_small.vtt',
#  'episode_125_large.vtt',
#  'episode_177_large.vtt',
#  'episode_135_small.vtt',
#  'episode_095_small.vtt',
#  'episode_125_small.vtt',
#  'episode_069_small.vtt',
#  'episode_071_large.vtt',
#  'episode_189_large.vtt',
#  'episode_121_large.vtt',
#  'episode_151_small.vtt',
#  'episode_142_large.vtt',
#  'episode_134_large.vtt',
#  'episode_139_large.vtt',
#  'episode_200_small.vtt',
#  'episode_193_small.vtt',
#  'episode_130_small.vtt',
#  'episode_107_small.vtt',
#  'episode_071_small.vtt',
#  'episode_152_small.vtt',
#  'episode_086_large.vtt',
#  'episode_160_small.vtt',
#  'episode_081_large.vtt',
#  'episode_142_small.vtt',
#  'episode_122_small.vtt',
#  'episode_085_small.vtt',
#  'episode_178_large.vtt',
#  'episode_130_large.vtt',
#  'episode_129_large.vtt',
#  'episode_167_small.vtt',
#  'episode_193_large.vtt',
#  'episode_184_large.vtt',
#  'episode_129_small.vtt',
#  'episode_149_small.vtt',
#  'episode_144_large.vtt',
#  'episode_199_small.vtt',
#  'episode_077_large.vtt',
#  'episode_176_large.vtt',
#  'episode_170_small.vtt',
#  'episode_072_large.vtt',
#  'episode_190_small.vtt',
#  'episode_088_large.vtt',
#  'episode_090_small.vtt',
#  'episode_157_large.vtt',
#  'episode_180_large.vtt',
#  'episode_108_large.vtt',
#  'episode_118_small.vtt',
#  'episode_155_small.vtt',
#  'episode_169_large.vtt',
#  'episode_197_large.vtt',
#  'episode_172_large.vtt',
#  'episode_188_small.vtt',
#  'episode_134_small.vtt',
#  'episode_173_large.vtt',
#  'episode_143_large.vtt',
#  'episode_132_small.vtt',
#  'episode_070_small.vtt',
#  'episode_198_small.vtt',
#  'episode_119_large.vtt',
#  'episode_146_large.vtt',
#  'episode_132_large.vtt',
#  'episode_197_small.vtt',
#  'episode_074_small.vtt',
#  'episode_174_large.vtt',
#  'episode_082_large.vtt',
#  'episode_109_large.vtt',
#  'episode_186_small.vtt',
#  'episode_068_small.vtt',
#  'episode_148_large.vtt',
#  'episode_162_large.vtt',
#  'episode_068_large.vtt',
#  'episode_148_small.vtt',
#  'episode_155_large.vtt',
#  'episode_185_large.vtt',
#  'episode_140_small.vtt',
#  'episode_146_small.vtt',
#  'episode_168_small.vtt',
#  'episode_165_small.vtt',
#  'episode_136_large.vtt',
#  'episode_137_small.vtt',
#  'episode_106_large.vtt',
#  'episode_167_large.vtt',
#  'episode_203_large.vtt',
#  'episode_101_small.vtt',
#  'episode_110_small.vtt',
#  'episode_111_large.vtt',
#  'episode_184_small.vtt',
#  'episode_180_small.vtt',
#  'episode_115_large.vtt',
#  'episode_120_small.vtt',
#  'episode_179_small.vtt',
#  'episode_150_small.vtt',
#  'episode_103_large.vtt',
#  'episode_126_small.vtt',
#  'episode_165_large.vtt',
#  'episode_111_small.vtt',
#  'episode_145_large.vtt',
#  'episode_166_small.vtt',
#  'episode_163_large.vtt',
#  'episode_112_small.vtt',
#  'episode_149_large.vtt',
#  'episode_075_small.vtt',
#  'episode_181_large.vtt',
#  'episode_108_small.vtt',
#  'episode_200_large.vtt',
#  'episode_124_small.vtt',
#  'episode_171_large.vtt',
#  'episode_077_small.vtt',
#  'episode_143_small.vtt',
#  'episode_057_large.vtt',
#  'episode_050_small.vtt',
#  'episode_029_large.vtt',
#  'episode_014_large.vtt',
#  'episode_050_large.vtt',
#  'episode_065_large.vtt',
#  'episode_005_large.vtt',
#  'episode_012_large.vtt',
#  'episode_034_large.vtt',
#  'episode_035_small.vtt',
#  'episode_003_large.vtt',
#  'episode_015_small.vtt',
#  'episode_042_small.vtt',
#  'episode_002_small.vtt',
#  'episode_024_large.vtt',
#  'episode_046_small.vtt',
#  'episode_025_large.vtt',
#  'episode_012_small.vtt',
#  'episode_021_small.vtt',
#  'episode_023_small.vtt',
#  'episode_060_large.vtt',
#  'episode_045_small.vtt',
#  'episode_059_small.vtt',
#  'episode_031_small.vtt',
#  'episode_019_small.vtt',
#  'episode_053_large.vtt',
#  'episode_036_large.vtt',
#  'episode_021_large.vtt',
#  'episode_044_small.vtt',
#  'episode_046_large.vtt',
#  'episode_019_large.vtt',
#  'episode_044_large.vtt',
#  'episode_018_small.vtt',
#  'episode_048_small.vtt',
#  'episode_024_small.vtt',
#  'episode_040_large.vtt',
#  'episode_007_large.vtt',
#  'episode_015_large.vtt',
#  'episode_027_small.vtt',
#  'episode_058_small.vtt',
#  'episode_022_large.vtt',
#  'episode_061_large.vtt',
#  'episode_064_large.vtt',
#  'episode_006_small.vtt',
#  'episode_032_small.vtt',
#  'episode_025_small.vtt',
#  'episode_018_large.vtt',
#  'episode_054_small.vtt',
#  'episode_029_small.vtt',
#  'episode_001_small.vtt',
#  'episode_030_large.vtt',
#  'episode_014_small.vtt',
#  'episode_009_small.vtt',
#  'episode_053_small.vtt',
#  'episode_042_large.vtt',
#  'episode_008_small.vtt',
#  'episode_045_large.vtt',
#  'episode_038_large.vtt',
#  'episode_057_small.vtt',
#  'episode_054_large.vtt',
#  'episode_016_small.vtt',
#  'episode_010_large.vtt',
#  'episode_066_small.vtt',
#  'episode_062_small.vtt',
#  'episode_063_large.vtt',
#  'episode_047_small.vtt',
#  'episode_020_small.vtt',
#  'episode_039_large.vtt',
#  'episode_002_large.vtt',
#  'episode_056_large.vtt',
#  'episode_052_small.vtt',
#  'episode_049_small.vtt',
#  'episode_023_large.vtt',
#  'episode_013_small.vtt',
#  'episode_047_large.vtt',
#  'episode_062_large.vtt',
#  'episode_065_small.vtt',
#  'episode_061_small.vtt',
#  'episode_036_small.vtt',
#  'episode_035_large.vtt',
#  'episode_017_small.vtt',
#  'episode_030_small.vtt',
#  'episode_063_small.vtt',
#  'episode_001_large.vtt',
#  'episode_032_large.vtt',
#  'episode_043_large.vtt',
#  'episode_040_small.vtt',
#  'episode_037_large.vtt',
#  'episode_048_large.vtt',
#  'episode_055_small.vtt',
#  'episode_064_small.vtt',
#  'episode_027_large.vtt',
#  'episode_005_small.vtt',
#  'episode_004_large.vtt',
#  'episode_041_small.vtt',
#  'episode_056_small.vtt',
#  'episode_051_large.vtt',
#  'episode_006_large.vtt',
#  'episode_028_large.vtt',
#  'episode_007_small.vtt',
#  'episode_034_small.vtt',
#  'episode_004_small.vtt',
#  'episode_016_large.vtt',
#  'episode_026_small.vtt',
#  'episode_020_large.vtt',
#  'episode_011_large.vtt',
#  'episode_060_small.vtt',
#  'episode_041_large.vtt',
#  'episode_033_large.vtt',
#  'episode_058_large.vtt',
#  'episode_039_small.vtt',
#  'episode_013_large.vtt',
#  'episode_055_large.vtt',
#  'episode_033_small.vtt',
#  'episode_059_large.vtt',
#  'episode_038_small.vtt',
#  'episode_009_large.vtt',
#  'episode_010_small.vtt',
#  'episode_037_small.vtt',
#  'episode_052_large.vtt',
#  'episode_022_small.vtt',
#  'episode_003_small.vtt',
#  'episode_049_large.vtt',
#  'episode_031_large.vtt',
#  'episode_043_small.vtt',
#  'episode_017_large.vtt',
#  'episode_008_large.vtt',
#  'episode_028_small.vtt',
#  'episode_051_small.vtt',
#  'episode_011_small.vtt',
#  'episode_026_large.vtt',
#  'Untitled project.gscript']

# %%
file_path = '/content/drive/My Drive/text/lex_fridman_vtt/episode_189_large.vtt'
# Open the VTT file and read its contents
with open('/content/drive/My Drive/text/lex_fridman_vtt/episode_189_large.vtt', 'r') as file:
    contents = file.read()

# Print the resulting text content
print(contents)
# Out:
# WEBVTT
#
# 00:00.000 --> 00:02.760
#  The following is a conversation with David Sinclair.
#
# 00:02.760 --> 00:06.200
#  He's a professor in the Department of Genetics at Harvard
#
# 00:06.200 --> 00:08.920
#  and co director of the Paul F. Glenn Center
#
# 00:08.920 --> 00:12.280
#  for the Biology of Aging at Harvard Medical School.
#
# 00:12.280 --> 00:13.280
#  He's the author of the book,
#
# 00:13.280 --> 00:16.840
#  Lifespan and co founder of several biotech companies.
#
# 00:16.840 --> 00:20.800
#  He works on turning age into an engineering problem
#
# 00:20.800 --> 00:22.160
#  and solving it.
#
# 00:22.160 --> 00:23.960
#  Driven by a vision of a world
#
# 00:23.960 --> 00:25.960
#  where billions of people can live much longer
#
# 00:25.960 --> 00:28.160
#  and much healthier lives.
#
# 00:28.160 --> 00:30.360
#  Quick mention of our sponsors,
#
# 00:30.360 --> 00:33.400
#  Onnit, Clear, National Instruments,
#
# 00:33.400 --> 00:36.840
#  and I, SimpliSafe and Linode.
#
# 00:36.840 --> 00:40.040
#  Check them out in the description to support this podcast.
#
# 00:40.040 --> 00:42.780
#  As a side note, let me say that longevity research
#
# 00:42.780 --> 00:45.880
#  challenges us to think how science and engineering
#
# 00:45.880 --> 00:47.640
#  will change society.
#
# 00:47.640 --> 00:50.400
#  Imagine if we can live 100,000 years,
#
# 00:50.400 --> 00:51.920
#  even under controlled conditions,
#
# 00:51.920 --> 00:53.720
#  like in a spaceship say,
#
# 00:53.720 --> 00:55.960
#  then suddenly a trip to Alpha Centauri
#
# 00:55.960 --> 00:58.840
#  that is a 4.37 light years away
#
# 00:58.840 --> 01:01.280
#  takes a single human lifespan.
#
# 01:01.280 --> 01:05.160
#  And on the psychological, maybe even philosophical level,
#
# 01:05.160 --> 01:08.720
#  as the horizons of death drifts farther into the distance,
#
# 01:08.720 --> 01:11.120
#  how will our search for meaning change?
#
# 01:11.120 --> 01:13.080
#  Does meaning require death
#
# 01:13.080 --> 01:15.720
#  or does it merely require struggle?
#
# 01:15.720 --> 01:19.440
#  Reprogramming our biology will require us to delve deeper
#
# 01:19.440 --> 01:23.680
#  into understanding the human mind and the robot mind.
#
# 01:23.680 --> 01:26.600
#  Both of these efforts are as exciting of a journey
#
# 01:26.600 --> 01:28.160
#  as I can imagine.
#
# 01:28.160 --> 01:30.320
#  This is the Lex Friedman Podcast
#
# 01:30.320 --> 01:33.400
#  and here is my conversation with David Sinclair.
#
# 01:34.360 --> 01:38.320
#  I usually feel like the same person when I was 12.
#
# 01:38.320 --> 01:42.460
#  Like when I, right now, as I think about myself,
#
# 01:42.460 --> 01:45.040
#  I feel like exactly the same person
#
# 01:45.040 --> 01:46.400
#  that I was when I was 12.
#
# 01:46.400 --> 01:51.400
#  And yet, I am getting older, both body and mind,
#
# 01:51.400 --> 01:54.240
#  and still feel like time hasn't passed at all.
#
# 01:54.240 --> 01:56.880
#  Do you feel this tension in yourself
#
# 01:56.880 --> 02:01.000
#  that you're the same person and yet you're aging?
#
# 02:01.000 --> 02:04.640
#  Yeah, I have this tension that I'm still a kid,
#
# 02:04.640 --> 02:05.880
#  but that helps in my career.
#
# 02:05.880 --> 02:07.920
#  Scientists need to have a wonder about the world
#
# 02:07.920 --> 02:10.520
#  and you don't wanna grow up at 12 year olds
#
# 02:10.520 --> 02:13.380
#  and even younger, I would say six, seven year olds.
#
# 02:13.380 --> 02:16.560
#  I've still got that boy in me and I can look at things.
#
# 02:16.560 --> 02:18.240
#  It's a gift, I think, that I can see things
#
# 02:18.240 --> 02:19.960
#  for the first time if I choose to,
#
# 02:19.960 --> 02:23.160
#  and then explain them as I would to a six year old
#
# 02:23.160 --> 02:24.960
#  because I am that mentally.
#
# 02:24.960 --> 02:26.720
#  But on the other hand, I'm getting older, right?
#
# 02:26.720 --> 02:29.240
#  I run a lab of 20 people at Harvard.
#
# 02:29.240 --> 02:33.520
#  I've got a book, I've got science to do, companies to run,
#
# 02:33.520 --> 02:35.680
#  and so I have to, on most days,
#
# 02:35.680 --> 02:38.160
#  just pretend to be a grownup and be mature,
#
# 02:38.160 --> 02:40.640
#  but I definitely don't feel that way.
#
# 02:40.640 --> 02:43.400
#  There's something I really appreciated
#
# 02:43.400 --> 02:44.920
#  in opening your book.
#
# 02:44.920 --> 02:46.920
#  You talked about your grandmother.
#
# 02:46.920 --> 02:50.380
#  And on this kind of theme, on this kind of topic,
#
# 02:51.240 --> 02:53.720
#  she, first of all, had a big influence on you.
#
# 02:53.720 --> 02:56.540
#  My grandmother had a big influence on me.
#
# 02:57.800 --> 02:59.080
#  And you also mentioned this poem
#
# 02:59.080 --> 03:03.760
#  by the author of Winnie the Pooh, Alan Alexander Milne.
#
# 03:04.720 --> 03:06.120
#  Maybe I can read it real quick
#
# 03:06.120 --> 03:10.280
#  because I love, on the topic of being children,
#
# 03:10.280 --> 03:12.560
#  when I was one, I had just begun.
#
# 03:12.560 --> 03:14.800
#  When I was two, I was nearly new.
#
# 03:14.800 --> 03:17.240
#  When I was three, I was hardly me.
#
# 03:17.240 --> 03:19.840
#  When I was four, I was not much more.
#
# 03:19.840 --> 03:24.320
#  When I was five, I was just alive, but now I am six.
#
# 03:24.320 --> 03:27.480
#  I am as clever, as clever, so I think I'll be six,
#
# 03:27.480 --> 03:29.600
#  now, forever and ever.
#
# 03:31.440 --> 03:36.440
#  So this idea of being six and staying six forever,
#
# 03:37.720 --> 03:39.320
#  being youthful, being curious,
#
# 03:39.320 --> 03:43.360
#  being childlike, this and other things,
#
# 03:43.360 --> 03:46.760
#  what influence has your grandmother had
#
# 03:46.760 --> 03:51.540
#  in your thinking about life, about death, about love?
#
# 03:53.200 --> 03:54.920
#  Yeah, I was getting misty eyed as you read that
#
# 03:54.920 --> 03:58.040
#  because that poem was read to me very often,
#
# 03:58.040 --> 03:59.520
#  if not every day, by my grandmother,
#
# 03:59.520 --> 04:01.400
#  who partially raised me.
#
# 04:02.300 --> 04:06.420
#  And she was as much a bohemian as an artist, philosopher.
#
# 04:06.420 --> 04:08.120
#  And she's one of those people
#
# 04:08.120 --> 04:09.760
#  that wouldn't talk about the little things.
#
# 04:09.760 --> 04:11.560
#  She said, I hate small talk.
#
# 04:11.560 --> 04:13.960
#  Don't talk to me about politics or the weather.
#
# 04:13.960 --> 04:16.920
#  Yeah, talk to me about human beings and culture.
#
# 04:16.920 --> 04:18.040
#  So I was raised on that,
#
# 04:18.040 --> 04:20.600
#  and this poem was one that she read to me often
#
# 04:20.600 --> 04:25.600
#  because she knew that the mind of a child is precious,
#
# 04:26.040 --> 04:28.520
#  it's honest, it's pure.
#
# 04:28.520 --> 04:31.480
#  And she grew up during the Second World War
#
# 04:31.480 --> 04:35.680
#  and in Hungary and Budapest witnessed the worst of humanity.
#
# 04:35.680 --> 04:40.060
#  She was trying to save a whole group of Jewish friends
#
# 04:40.060 --> 04:43.180
#  in her apartment, saw what happened after the World War,
#
# 04:43.180 --> 04:47.760
#  which was there was, the Russians were in control
#
# 04:47.760 --> 04:50.320
#  and locals weren't necessarily treated well
#
# 04:50.320 --> 04:52.520
#  if they were rebellious, which she was.
#
# 04:52.520 --> 04:54.440
#  And then there was the revolution in 56,
#
# 04:54.440 --> 04:57.240
#  which she was part of and had to escape the country.
#
# 04:57.240 --> 05:01.260
#  So she saw what can happen when humans do their worst.
#
# 05:01.260 --> 05:05.240
#  And her words to me, expressed in part through that poem
#
# 05:05.240 --> 05:09.560
#  was, David, always stay young and innocent
#
# 05:09.560 --> 05:11.600
#  and have wonder about the world,
#
# 05:11.600 --> 05:15.440
#  and then do your best to make humanity the best it can be.
#
# 05:15.440 --> 05:18.340
#  And that's who I am, that's what I live for,
#
# 05:18.340 --> 05:19.800
#  that's what I get up in the morning to do
#
# 05:19.800 --> 05:21.640
#  is to leave the world a better place
#
# 05:21.640 --> 05:23.180
#  and show to whoever's watching us,
#
# 05:23.180 --> 05:26.760
#  whether it's aliens or some future human historian,
#
# 05:26.760 --> 05:29.520
#  that we can do better than we did in the 20th century.
#
# 05:31.240 --> 05:33.200
#  You know, we mentioned offline this idea
#
# 05:33.200 --> 05:34.920
#  of bringing people back to life
#
# 05:34.920 --> 05:38.240
#  through artificial intelligence,
#
# 05:38.240 --> 05:40.880
#  sort of, I don't know if you've seen videos
#
# 05:40.880 --> 05:45.200
#  of basically animating people back to life,
#
# 05:45.200 --> 05:47.960
#  meaning whether it's, for me personally,
#
# 05:47.960 --> 05:51.600
#  I've been working on specifically about Albert Einstein,
#
# 05:51.600 --> 05:55.760
#  but also Alan Turing, Isaac Newton, and Richard Feynman.
#
# 05:56.740 --> 05:59.520
#  And it's an opportunity to bring people
#
# 05:59.520 --> 06:02.360
#  that meant a lot to others in the world
#
# 06:02.360 --> 06:06.240
#  and animate them and be able to have a conversation
#
# 06:06.240 --> 06:10.300
#  with them at first to try to visually,
#
# 06:12.740 --> 06:17.200
#  visually explore the full richness of character
#
# 06:17.200 --> 06:18.800
#  that they had as they struggle
#
# 06:18.800 --> 06:20.880
#  with the ideas of the modern age.
#
# 06:20.880 --> 06:24.120
#  Sort of, it's less about bringing back their mind
#
# 06:24.120 --> 06:27.440
#  and more bringing back the visual quirks
#
# 06:27.440 --> 06:28.960
#  that made them who they are.
#
# 06:28.960 --> 06:30.960
#  And then maybe in the future,
#
# 06:30.960 --> 06:33.200
#  it's using the textual, the visual,
#
# 06:33.200 --> 06:38.200
#  the video, the audio data to actually compress
#
# 06:38.600 --> 06:41.080
#  down the person for who they are
#
# 06:41.080 --> 06:42.460
#  and be able to generate text.
#
# 06:42.460 --> 06:44.520
#  There's a few companies, there's Replica,
#
# 06:44.520 --> 06:46.920
#  which is a chat engine that was born
#
# 06:46.920 --> 06:48.460
#  out of the idea of bringing,
#
# 06:48.460 --> 06:53.440
#  the founder lost her friend to,
#
# 06:53.440 --> 06:55.840
#  he got run over by a car.
#
# 06:55.840 --> 06:59.740
#  And the initial reason she founded the company
#
# 06:59.740 --> 07:02.840
#  was trying to just have a conversation with her friend.
#
# 07:02.840 --> 07:07.400
#  She trained machine learning, natural language system
#
# 07:07.400 --> 07:09.480
#  on the texts that they exchange with each other
#
# 07:09.480 --> 07:11.880
#  and try, she had a conversation with him
#
# 07:11.880 --> 07:13.880
#  sort of after he was gone.
#
# 07:13.880 --> 07:16.880
#  And it's very, the conversation was very trivial.
#
# 07:16.880 --> 07:21.200
#  It was obvious that it's AI agent,
#
# 07:21.200 --> 07:23.200
#  but it gave her solace.
#
# 07:23.200 --> 07:26.080
#  It made her actually feel really good.
#
# 07:26.080 --> 07:27.920
#  And that's the way I wonder if it's possible
#
# 07:27.920 --> 07:30.840
#  to bring back people that are,
#
# 07:30.840 --> 07:32.520
#  that mean something to us personally,
#
# 07:32.520 --> 07:36.640
#  not just Einstein, but people that we've lost
#
# 07:36.640 --> 07:40.480
#  and in that way achieve a kind of small
#
# 07:40.480 --> 07:42.680
#  artificial immortality.
#
# 07:42.680 --> 07:44.700
#  I don't know if you think about this kind of stuff.
#
# 07:44.700 --> 07:46.800
#  Well, I definitely think about a lot of things.
#
# 07:46.800 --> 07:47.640
#  That one's a really good one.
#
# 07:47.640 --> 07:49.160
#  There's a great Black Mirror episode
#
# 07:49.160 --> 07:52.840
#  about the wife who brings back the boyfriend or husband.
#
# 07:52.840 --> 07:54.280
#  I think one of the challenges
#
# 07:54.280 --> 07:55.520
#  with bringing back Richard Feynman
#
# 07:55.520 --> 07:58.080
#  would be to capture his sense of humor,
#
# 07:58.080 --> 07:59.300
#  but that would be awesome.
#
# 07:59.300 --> 08:00.940
#  But yeah, bringing back loved ones would be great,
#
# 08:00.940 --> 08:05.940
#  especially if they're young and they die early,
#
# 08:07.680 --> 08:09.180
#  though it may hold you back from moving on.
#
# 08:09.180 --> 08:11.840
#  That's another thing that could happen as a negative.
#
# 08:11.840 --> 08:12.680
#  But I think that's great.
#
# 08:12.680 --> 08:14.680
#  And I also think that it's gonna be possible,
#
# 08:14.680 --> 08:17.260
#  especially when we're recording some of us,
#
# 08:17.260 --> 08:18.440
#  every aspect of our lives,
#
# 08:18.440 --> 08:22.600
#  whether it's our face or things we see, right?
#
# 08:22.600 --> 08:26.040
#  Eventually one day, everything we see can be recorded.
#
# 08:26.040 --> 08:28.980
#  And then you can build somebody's experience
#
# 08:28.980 --> 08:31.840
#  and thoughts, speech,
#
# 08:31.840 --> 08:35.000
#  and you will have replicas of everybody,
#
# 08:35.000 --> 08:36.440
#  at least digitally,
#
# 08:36.440 --> 08:38.740
#  and physically you could do that too one day.
#
# 08:38.740 --> 08:40.360
#  But that's a good idea,
#
# 08:40.360 --> 08:42.640
#  especially because there are people that I'd like to meet,
#
# 08:42.640 --> 08:44.940
#  and I think it's easier than building a time machine.
#
# 08:44.940 --> 08:47.320
#  One person I'd love to meet is Benjamin Franklin.
#
# 08:47.320 --> 08:48.160
#  Really?
#
# 08:48.160 --> 08:50.720
#  Well, I wouldn't go back in time.
#
# 08:50.720 --> 08:53.140
#  I would, but I'd prefer to bring him into the future
#
# 08:53.140 --> 08:57.040
#  and say, can you believe we have this thinking machine
#
# 08:57.040 --> 08:58.420
#  in our pockets now?
#
# 08:58.420 --> 09:00.240
#  And just see the look on his face
#
# 09:00.240 --> 09:01.320
#  as to where humanity has come.
#
# 09:01.320 --> 09:03.480
#  Because I think of him as a modern guy
#
# 09:03.480 --> 09:05.480
#  that just was before his time.
#
# 09:05.480 --> 09:08.520
#  Yeah, so you're thinking Benjamin Franklin the scientist,
#
# 09:08.520 --> 09:10.400
#  not Benjamin Franklin the political thing.
#
# 09:10.400 --> 09:13.040
#  Because he'd be very upset with Congress right now.
#
# 09:13.040 --> 09:13.880
#  Right.
#
# 09:13.880 --> 09:16.160
#  So maybe talk to him about science and technology,
#
# 09:16.160 --> 09:18.160
#  not politics.
#
# 09:18.160 --> 09:19.600
#  Or maybe just don't get him on Twitter
#
# 09:19.600 --> 09:22.400
#  because he'll be very upset with human civilization.
#
# 09:22.400 --> 09:25.360
#  You know, I wonder what their personalities are like.
#
# 09:25.360 --> 09:28.640
#  Isaac Newton, it does seem complicated
#
# 09:28.640 --> 09:30.480
#  to figure out what their personality is like.
#
# 09:30.480 --> 09:33.320
#  Even Friedrich Nietzsche, who I also thought about.
#
# 09:33.320 --> 09:36.800
#  Feynman is, we just have enough video
#
# 09:36.800 --> 09:39.360
#  where we get the full kind of,
#
# 09:39.360 --> 09:42.440
#  I mean, it shows you how important it is
#
# 09:42.440 --> 09:47.440
#  to get not the official kind of book level presentation
#
# 09:47.560 --> 09:49.560
#  of a human, but the authentic,
#
# 09:49.560 --> 09:51.960
#  the full spectrum of humanity.
#
# 09:51.960 --> 09:54.420
#  You mentioned collecting data about a person,
#
# 09:54.420 --> 09:57.280
#  collecting the whole thing, the whole of life,
#
# 09:57.280 --> 09:59.480
#  the ups and downs, the embarrassing stuff,
#
# 09:59.480 --> 10:01.600
#  the beautiful stuff, not just the things
#
# 10:01.600 --> 10:03.160
#  that's condensed into a book.
#
# 10:03.160 --> 10:05.880
#  And then with Feynman, you start to see that a little bit.
#
# 10:05.880 --> 10:07.940
#  Through conversations, you start to see peaks
#
# 10:07.940 --> 10:09.240
#  of like that genius.
#
# 10:09.240 --> 10:12.920
#  And then through stories about him from others.
#
# 10:12.920 --> 10:15.680
#  And then certainly you, the sad thing
#
# 10:15.680 --> 10:17.720
#  about Alan Turing, for example,
#
# 10:17.720 --> 10:22.240
#  is there's very little, if any, recording of him.
#
# 10:22.240 --> 10:24.160
#  In fact, I haven't been able to find recording
#
# 10:24.160 --> 10:27.440
#  allegedly there's supposed to be a recording of him
#
# 10:27.440 --> 10:29.720
#  doing some kind of a radio broadcast,
#
# 10:29.720 --> 10:32.120
#  but I haven't been able to find anything.
#
# 10:32.120 --> 10:35.680
#  And so that's truly sad that it feels like
#
# 10:35.680 --> 10:40.360
#  it makes you realize how the upside,
#
# 10:40.360 --> 10:44.000
#  how nice it is to collect data about a person,
#
# 10:44.000 --> 10:46.280
#  to capture that person.
#
# 10:46.280 --> 10:48.740
#  That's the upside of the modern internet age,
#
# 10:48.740 --> 10:51.340
#  the digital age, that that information,
#
# 10:51.340 --> 10:54.200
#  yeah, creates a kind of immortality.
#
# 10:55.700 --> 10:57.100
#  And then you can choose to highlight
#
# 10:57.100 --> 10:58.220
#  the best parts of the person,
#
# 10:58.220 --> 11:00.580
#  maybe throw away the ugly parts
#
# 11:00.580 --> 11:03.460
#  and celebrate them even after they're gone.
#
# 11:03.460 --> 11:05.100
#  So that's a really interesting opportunity.
#
# 11:05.100 --> 11:07.900
#  You've also mentioned to me offline
#
# 11:07.900 --> 11:11.060
#  that you're really excited about all the different wearables
#
# 11:11.060 --> 11:14.020
#  and all the different ways we can collect information
#
# 11:14.020 --> 11:18.060
#  about our bodies, about the whole thing.
#
# 11:18.060 --> 11:21.180
#  What's most exciting to you in terms of collecting
#
# 11:21.180 --> 11:26.180
#  the biological data about a human being?
#
# 11:27.860 --> 11:29.300
#  Well, so I'm a biologist.
#
# 11:29.300 --> 11:33.120
#  I find animals and humans as machines very interesting.
#
# 11:34.060 --> 11:36.500
#  It's one of the reasons I didn't become an engineer
#
# 11:36.500 --> 11:37.340
#  or a surgeon.
#
# 11:37.340 --> 11:39.580
#  I wanted to understand how we actually are built.
#
# 11:40.580 --> 11:45.580
#  And so I think a lot about machines merging with humans.
#
# 11:46.020 --> 11:49.020
#  And the first of that are the bio wearables.
#
# 11:49.020 --> 11:51.380
#  And so I talked a lot about this, I wrote about it
#
# 11:51.380 --> 11:54.120
#  in Lifespan, the book, and pictured a future
#
# 11:54.120 --> 11:56.860
#  where you would be monitored constantly
#
# 11:56.860 --> 11:59.280
#  so that you wouldn't suddenly have a heart attack,
#
# 11:59.280 --> 12:00.220
#  you'd know that was coming,
#
# 12:00.220 --> 12:02.620
#  or you wouldn't go to the doctor
#
# 12:02.620 --> 12:05.660
#  and they don't know if you need an antibiotic or not.
#
# 12:07.540 --> 12:09.980
#  Long term, how old are you, how to fix things,
#
# 12:09.980 --> 12:11.540
#  what should you eat, what should you take,
#
# 12:11.540 --> 12:12.980
#  what should your doctor do?
#
# 12:12.980 --> 12:16.100
#  These devices, I predicted, would be smarter,
#
# 12:16.100 --> 12:18.100
#  better educated than your physician
#
# 12:18.100 --> 12:19.700
#  and would augment them.
#
# 12:19.700 --> 12:21.460
#  And then there'd be a human that would just tick off
#
# 12:21.460 --> 12:24.300
#  to see if it's correct and they approve.
#
# 12:24.300 --> 12:26.820
#  I also was predicting in the book
#
# 12:26.820 --> 12:30.180
#  that we would have video conferences with our doctors
#
# 12:30.180 --> 12:32.020
#  and that medicines would be delivered,
#
# 12:32.020 --> 12:33.940
#  initially by courier, but eventually by drones
#
# 12:33.940 --> 12:36.220
#  and get it to you sometimes in an emergency.
#
# 12:36.220 --> 12:37.980
#  And that we could even have pills
#
# 12:37.980 --> 12:41.820
#  that were synthesized or delivered in your kitchen
#
# 12:41.820 --> 12:43.920
#  and combined certainly.
#
# 12:43.920 --> 12:47.100
#  What's amazing about that is that, what are we now,
#
# 12:47.100 --> 12:50.180
#  two years since the book came out, even less,
#
# 12:50.180 --> 12:52.380
#  and that future is basically here already.
#
# 12:52.380 --> 12:56.860
#  COVID 19 accelerated that incredibly.
#
# 12:56.860 --> 12:58.480
#  So where we're at now in society is,
#
# 12:58.480 --> 13:00.620
#  if you wanna pay for it, you can have a blood test
#
# 13:00.620 --> 13:03.580
#  that will detect cancer 10, 20 years earlier than it would
#
# 13:03.580 --> 13:05.340
#  before it forms a tumor.
#
# 13:05.340 --> 13:07.940
#  You can, of course, do your genome very cheaply
#
# 13:07.940 --> 13:09.380
#  for less than $100 now.
#
# 13:10.840 --> 13:12.960
#  There are bio wearables already I wear,
#
# 13:12.960 --> 13:17.180
#  this ring from Aura that I have a number of years of data.
#
# 13:17.180 --> 13:19.220
#  I've been doing blood tests for the last 12 years
#
# 13:19.220 --> 13:22.580
#  with a company called Inside Tracker, which I consult for.
#
# 13:22.580 --> 13:24.220
#  And so I have all of that data as well.
#
# 13:24.220 --> 13:27.700
#  And there's 34 different parameters on my testosterone,
#
# 13:27.700 --> 13:30.020
#  my blood glucose, my inflammation.
#
# 13:30.020 --> 13:32.700
#  And I use all that data to, of course,
#
# 13:32.700 --> 13:34.720
#  I wear a watch that measures things as well.
#
# 13:34.720 --> 13:39.280
#  I use that data to keep my body in optimal shape.
#
# 13:39.280 --> 13:40.660
#  So I'm now 51.
#
# 13:40.660 --> 13:42.140
#  And according to those parameters,
#
# 13:42.140 --> 13:45.740
#  I'm at least as good as someone in their early 40s.
#
# 13:45.740 --> 13:47.200
#  And if I really work at it,
#
# 13:47.200 --> 13:52.020
#  I can get my biochemistry down to early to mid 30s,
#
# 13:52.020 --> 13:56.220
#  though I like to now eat a little dessert once in a while.
#
# 13:56.220 --> 13:58.700
#  So that's the future we're in right now.
#
# 13:58.700 --> 14:00.900
#  Anyone can do what I just said.
#
# 14:00.900 --> 14:04.340
#  But in the very near future, just in the next few years,
#
# 14:04.340 --> 14:06.380
#  you can be wearing wearables.
#
# 14:06.380 --> 14:08.540
#  So I'm currently wearing a little,
#
# 14:08.540 --> 14:10.960
#  what's called a bio sticker.
#
# 14:10.960 --> 14:14.100
#  This one I just put on last night.
#
# 14:14.100 --> 14:18.580
#  It's about an inch long, a few millimeters.
#
# 14:18.580 --> 14:21.660
#  Yeah, for people just listening, it's on David's chest.
#
# 14:21.660 --> 14:23.180
#  It's just, how does it attach?
#
# 14:23.180 --> 14:24.300
#  It's just kind of.
#
# 14:24.300 --> 14:25.380
#  It sticks on. Sticks on.
#
# 14:25.380 --> 14:27.740
#  Yeah, so on one side you have an on button that you press.
#
# 14:27.740 --> 14:30.500
#  The lights come on, flashes four times, it's good to go.
#
# 14:30.500 --> 14:32.980
#  It immediately syncs to your phone.
#
# 14:32.980 --> 14:37.260
#  And this one, it's called a bio button, a nice name.
#
# 14:37.260 --> 14:39.460
#  And there's another one that I have that I haven't tried yet
#
# 14:39.460 --> 14:41.500
#  that does EKG on your heart.
#
# 14:41.500 --> 14:43.380
#  This is mainly for doctors to monitor patients
#
# 14:43.380 --> 14:45.620
#  that go home after a heart attack or surgery.
#
# 14:45.620 --> 14:48.940
#  But that's medical grade FDA approved device.
#
# 14:48.940 --> 14:51.260
#  So there will be a day, in fact, it's already here,
#
# 14:51.260 --> 14:55.260
#  that doctors are using these to get patients to go home
#
# 14:55.260 --> 14:59.460
#  and save a week in hospital, $2,000 at least
#
# 14:59.460 --> 15:00.940
#  for each patient.
#
# 15:00.940 --> 15:04.460
#  That's massive savings for the hospital.
#
# 15:04.460 --> 15:06.580
#  But ultimately what I'm excited about is a future
#
# 15:06.580 --> 15:10.760
#  that isn't that far off where everybody,
#
# 15:10.760 --> 15:11.780
#  certainly in developed countries,
#
# 15:11.780 --> 15:14.340
#  eventually these will cost a few cents and rechargeable.
#
# 15:14.340 --> 15:16.620
#  The only cost will be the software subscription
#
# 15:16.620 --> 15:19.220
#  that can be monitored constantly.
#
# 15:19.220 --> 15:21.020
#  And to give an idea what this is measuring me
#
# 15:21.020 --> 15:26.020
#  at a thousand times a second is my vibrations as I speak,
#
# 15:26.220 --> 15:29.580
#  my orientation, it already has told me this morning
#
# 15:29.580 --> 15:33.220
#  how I slept, where I slept, what side I slept on.
#
# 15:33.220 --> 15:37.000
#  We've got sneezing, coughing, body temperature,
#
# 15:37.000 --> 15:40.840
#  heart rate, heart of other parameters of the heart
#
# 15:40.840 --> 15:42.440
#  that would indicate heart health.
#
# 15:44.000 --> 15:49.000
#  These data are being used to now to predict sickness.
#
# 15:49.880 --> 15:53.640
#  So eventually we'll have just in the next year or so
#
# 15:53.640 --> 15:55.520
#  the ability to predict whether something
#
# 15:55.520 --> 15:58.160
#  or diagnose whether something is pneumonia
#
# 15:58.160 --> 16:02.840
#  or just a rhinovirus that can be treated or not.
#
# 16:02.840 --> 16:06.360
#  This is really going to not just revolutionize medicine,
#
# 16:06.360 --> 16:08.480
#  but I think extend lives dramatically.
#
# 16:08.480 --> 16:11.520
#  Because if I'm gonna have a heart attack next week
#
# 16:11.520 --> 16:14.440
#  and that's possible, this device should know that
#
# 16:14.440 --> 16:16.960
#  and I'll be in hospital before I even have it.
#
# 16:16.960 --> 16:19.280
#  Maybe you can talk a little bit about InsideTracker
#
# 16:19.280 --> 16:23.000
#  because I saw that there's some really cool things in there.
#
# 16:23.000 --> 16:25.960
#  Like it actually, so maybe you can talk about,
#
# 16:25.960 --> 16:29.240
#  I guess that you're collecting blood to give it the data.
#
# 16:29.240 --> 16:32.480
#  So, and it has like basic recommendations
#
# 16:32.480 --> 16:34.200
#  on how to improve your life.
#
# 16:34.200 --> 16:36.560
#  So we're not just talking about diseases, right?
#
# 16:36.560 --> 16:39.080
#  Like anticipating having a particular disease,
#
# 16:39.080 --> 16:41.840
#  but it's almost like guiding your trajectory to life,
#
# 16:41.840 --> 16:44.600
#  how to, whether it's extend your life
#
# 16:44.600 --> 16:46.680
#  or just live a more fulfilling,
#
# 16:46.680 --> 16:48.160
#  like improve the quality of life.
#
# 16:48.160 --> 16:50.600
#  I suppose this is the right way to say it.
#
# 16:50.600 --> 16:52.460
#  How does InsideTracker work?
#
# 16:52.460 --> 16:53.300
#  What the heck is it?
#
# 16:53.300 --> 16:55.080
#  Because I thought there was also pretty cool.
#
# 16:55.080 --> 16:55.920
#  Yeah.
#
# 16:55.920 --> 16:56.760
#  What is it?
#
# 16:56.760 --> 16:58.240
#  Is it something other people can use?
#
# 16:58.240 --> 16:59.720
#  You can definitely use it.
#
# 16:59.720 --> 17:02.040
#  You can sign up, it's consumer.
#
# 17:02.040 --> 17:04.440
#  It's like a company consumer facing company.
#
# 17:04.440 --> 17:06.040
#  It is, yeah.
#
# 17:06.040 --> 17:08.960
#  And I also want to democratize the ability
#
# 17:08.960 --> 17:11.000
#  to just take a mouth swab eventually.
#
# 17:11.000 --> 17:13.560
#  We don't need to have a blood test necessarily,
#
# 17:13.560 --> 17:14.640
#  but for now it's a blood test
#
# 17:14.640 --> 17:18.380
#  and you'd go to a lab core request in the US.
#
# 17:18.380 --> 17:19.840
#  It's also available overseas.
#
# 17:19.840 --> 17:22.540
#  You can upload your own data for a minimal cost
#
# 17:22.540 --> 17:26.560
#  and get the algorithms, the AI in the background
#
# 17:26.560 --> 17:27.880
#  to take that data,
#
# 17:27.880 --> 17:31.560
#  plot where you are against others in your age group
#
# 17:31.560 --> 17:34.120
#  in terms of health and longevity at bio age.
#
# 17:34.120 --> 17:36.000
#  They call it inner age,
#
# 17:36.000 --> 17:38.120
#  but also it provides recommendations.
#
# 17:38.120 --> 17:39.640
#  And this isn't just a bunch of BS.
#
# 17:39.640 --> 17:42.520
#  It sounds like it might be to say, I'll go eat this
#
# 17:42.520 --> 17:44.360
#  or go to that restaurant and order that,
#
# 17:44.360 --> 17:47.000
#  but it's actually based on the basic.
#
# 17:47.000 --> 17:49.800
#  This company has entered hundreds.
#
# 17:49.800 --> 17:51.760
#  Now it would be thousands of scientific papers
#
# 17:51.760 --> 17:53.160
#  into their database
#
# 17:53.160 --> 17:55.720
#  and hundreds of thousands of human data points.
#
# 17:55.720 --> 17:59.040
#  And they have tens of thousands of individuals
#
# 17:59.040 --> 18:00.360
#  that have been tracked over time
#
# 18:00.360 --> 18:02.920
#  and anonymously that data is used to say
#
# 18:02.920 --> 18:04.240
#  what works and what doesn't.
#
# 18:04.240 --> 18:05.720
#  If you eat that, what works?
#
# 18:05.720 --> 18:07.600
#  If you take that supplement, what works?
#
# 18:07.600 --> 18:09.620
#  And I was a coauthor on a paper that showed
#
# 18:09.620 --> 18:13.440
#  that the recommendations for food and supplements
#
# 18:15.040 --> 18:18.040
#  was better than the leading drug for type two diabetes.
#
# 18:18.920 --> 18:19.760
#  That's so cool.
#
# 18:19.760 --> 18:21.660
#  The idea that you can connect,
#
# 18:21.660 --> 18:24.880
#  like skipping the human having to do this work,
#
# 18:24.880 --> 18:27.380
#  you can connect the scientific papers,
#
# 18:27.380 --> 18:30.080
#  almost like meta analysis of the science
#
# 18:30.080 --> 18:32.480
#  connected to the individual data.
#
# 18:32.480 --> 18:35.400
#  And then based on that sort of connect your data
#
# 18:35.400 --> 18:37.880
#  to whatever the proper group is
#
# 18:37.880 --> 18:40.440
#  within the whatever the scientific paper is
#
# 18:40.440 --> 18:44.840
#  to make the suggestion of how like how that work
#
# 18:44.840 --> 18:47.120
#  applies to your life.
#
# 18:47.120 --> 18:49.640
#  And then that ultimately maps to like a recommendation
#
# 18:49.640 --> 18:51.240
#  of what you should do with your life.
#
# 18:51.240 --> 18:54.520
#  Like it all like this giant system
#
# 18:54.520 --> 18:55.700
#  that ultimately recommends
#
# 18:55.700 --> 18:58.440
#  you should drink more coffee or less.
#
# 18:58.440 --> 19:00.280
#  Right, and we'll have the genome in there as well.
#
# 19:00.280 --> 19:01.200
#  You can upload that.
#
# 19:01.200 --> 19:02.440
#  Yeah, it's awesome.
#
# 19:02.440 --> 19:04.640
#  So these programs will know us way better
#
# 19:04.640 --> 19:07.480
#  than we do and our doctors as well.
#
# 19:07.480 --> 19:08.960
#  The idea of going to a doctor once a year
#
# 19:08.960 --> 19:11.940
#  for an annual checkup and having males get a finger
#
# 19:11.940 --> 19:16.000
#  up their butt and you cough, that to me is a joke.
#
# 19:16.000 --> 19:18.140
#  That's medieval medicine.
#
# 19:18.140 --> 19:21.440
#  And that's very soon going to be seen as medieval.
#
# 19:21.440 --> 19:25.920
#  Yeah, to me as a computer science person,
#
# 19:25.920 --> 19:28.640
#  it's always upsetting to go to the doctor
#
# 19:28.640 --> 19:31.120
#  and just look at him and like realize
#
# 19:31.120 --> 19:33.160
#  you know nothing about me.
#
# 19:33.160 --> 19:38.160
#  Like you're making your like opinions based on like,
#
# 19:38.560 --> 19:42.540
#  it is very valuable, years of intuition building
#
# 19:42.540 --> 19:45.880
#  about basic symptoms, but you're just like it is medieval.
#
# 19:45.880 --> 19:47.200
#  They're very good at it.
#
# 19:47.200 --> 19:51.360
#  In fact, doctors in medieval times were probably damn good
#
# 19:51.360 --> 19:53.600
#  at working with very little.
#
# 19:53.600 --> 19:58.520
#  But the thing is, I'd rather prefer a doctor
#
# 19:58.520 --> 20:00.040
#  that doesn't really know what they're doing,
#
# 20:00.040 --> 20:02.200
#  but has a huge amount of data to work with.
#
# 20:03.080 --> 20:03.920
#  Well, you're right.
#
# 20:03.920 --> 20:05.600
#  And many of my good friends are doctors.
#
# 20:05.600 --> 20:06.520
#  I work at Harvard.
#
# 20:06.520 --> 20:09.640
#  So I'm not against the profession at all.
#
# 20:09.640 --> 20:11.680
#  But I think that they need just as much help
#
# 20:11.680 --> 20:13.480
#  as anyone else does.
#
# 20:13.480 --> 20:15.320
#  We wouldn't drive a car without a dashboard.
#
# 20:15.320 --> 20:16.140
#  We wouldn't think of it.
#
# 20:16.140 --> 20:18.720
#  So why would doctors do the same?
#
# 20:18.720 --> 20:21.400
#  If we could, could we step back to the big,
#
# 20:21.400 --> 20:23.680
#  profound, philosophical, both tragic
#
# 20:23.680 --> 20:25.500
#  and beautiful question about age?
#
# 20:26.360 --> 20:28.700
#  How and why do we age?
#
# 20:28.700 --> 20:31.520
#  Is it from an engineering perspective?
#
# 20:31.520 --> 20:33.720
#  You said you like the biological machine.
#
# 20:33.720 --> 20:37.760
#  Is that a feature or a bug of the biological machine?
#
# 20:37.760 --> 20:40.720
#  It is both a bug and a feature.
#
# 20:40.720 --> 20:44.640
#  Evolutionary speaking, we only live as long as we need to
#
# 20:44.640 --> 20:46.280
#  to replace ourselves efficiently.
#
# 20:47.360 --> 20:49.320
#  If you're a mouse, you're only gonna live two
#
# 20:49.320 --> 20:50.600
#  and a half years, three years.
#
# 20:50.600 --> 20:51.880
#  You're probably gonna die of starvation,
#
# 20:51.880 --> 20:54.440
#  predation, freezing in the winter.
#
# 20:54.440 --> 20:57.120
#  So they divert most of their resources
#
# 20:57.120 --> 20:59.320
#  to reproducing rapidly,
#
# 20:59.320 --> 21:00.960
#  but they don't put a lot of energy
#
# 21:00.960 --> 21:04.320
#  into preserving their soma, which is their body.
#
# 21:04.320 --> 21:06.640
#  Conversely, a baleen type of whale,
#
# 21:06.640 --> 21:09.320
#  a bowhead whale in particular will live hundreds of years
#
# 21:09.320 --> 21:11.060
#  because they're at the top of the food chain
#
# 21:11.060 --> 21:12.640
#  and they can live as long as they want.
#
# 21:12.640 --> 21:15.120
#  So they breed slowly and build a body that lasts.
#
# 21:15.120 --> 21:17.400
#  We're somewhere in between because we've, you know,
#
# 21:17.400 --> 21:19.680
#  we've really only just come out of the savannas
#
# 21:19.680 --> 21:22.080
#  where we could be picked off by a cat.
#
# 21:22.080 --> 21:25.400
#  We were pretty wimpy going back 6 million years ago.
#
# 21:25.400 --> 21:30.080
#  So we actually need to evolve quicker than evolution will.
#
# 21:30.080 --> 21:33.560
#  And that's why we can use our oversized brains
#
# 21:33.560 --> 21:36.140
#  and intuition to give us what evolution
#
# 21:36.140 --> 21:38.280
#  not only didn't give us, but took away from us.
#
# 21:38.280 --> 21:40.680
#  Now we're pathetic, look at our bodies.
#
# 21:40.680 --> 21:42.920
#  These arms, if any of us, even the strongest person
#
# 21:42.920 --> 21:45.000
#  in the world went in a cage with a chimpanzee,
#
# 21:45.000 --> 21:47.400
#  the chimp could knock that person's head off, no question.
#
# 21:47.400 --> 21:48.240
#  So we're pathetic.
#
# 21:48.240 --> 21:50.280
#  So we need to engineer ourselves to be healthier
#
# 21:50.280 --> 21:51.580
#  and longer lived.
#
# 21:51.580 --> 21:55.680
#  So getting to aging, we can do better, right?
#
# 21:55.680 --> 21:57.260
#  Whales do way better.
#
# 21:57.260 --> 21:59.500
#  We're trying to learn how whales do that.
#
# 21:59.500 --> 22:03.300
#  And if you ask really anybody in the field now, professor,
#
# 22:03.300 --> 22:07.360
#  they'll say there are eight or nine hallmarks of aging,
#
# 22:07.360 --> 22:11.520
#  which are really, it's a word for causes of aging.
#
# 22:11.520 --> 22:13.500
#  So that you probably have heard of some of these,
#
# 22:13.500 --> 22:16.600
#  your listeners will have loss of telomeres,
#
# 22:16.600 --> 22:19.600
#  the ends of the chromosomes, like the little ends
#
# 22:19.600 --> 22:21.880
#  of shoelaces, that kind of thing.
#
# 22:21.880 --> 22:24.880
#  They get too short, cells stop dividing, become senescent.
#
# 22:24.880 --> 22:28.560
#  They become, they put out what are called mitogens
#
# 22:28.560 --> 22:31.040
#  that cause cancer and inflammatory molecules.
#
# 22:31.040 --> 22:34.280
#  So that's another aspect of aging, cellular senescence.
#
# 22:34.280 --> 22:35.880
#  Another one is loss of the energetic.
#
# 22:35.880 --> 22:38.680
#  So mitochondria, the battery packs wind down.
#
# 22:39.720 --> 22:43.080
#  There's a whole bunch, stem cells, proteostasis.
#
# 22:43.080 --> 22:45.440
#  Well, these are our Achilles heels that I'm talking about.
#
# 22:45.440 --> 22:48.400
#  They're a common amongst all life forms, really.
#
# 22:48.400 --> 22:51.640
#  But if you want me to jump to the chases to where,
#
# 22:51.640 --> 22:54.400
#  what is the upstream defining factor?
#
# 22:54.400 --> 22:57.300
#  If we boil it down, what do we get?
#
# 22:57.300 --> 22:59.700
#  So most biologists would say, you can't boil it down.
#
# 22:59.700 --> 23:01.200
#  It's too complex.
#
# 23:01.200 --> 23:03.640
#  I would say you can boil it down to an equation,
#
# 23:03.640 --> 23:05.860
#  which is the preservation of information
#
# 23:05.860 --> 23:09.040
#  and loss due to entropy, i.e. noise.
#
# 23:09.040 --> 23:11.100
#  And that is the basis of my research.
#
# 23:12.380 --> 23:14.820
#  It originally came out of discoveries in yeast cells,
#
# 23:14.820 --> 23:17.240
#  where I went to MIT in the 1990s.
#
# 23:17.240 --> 23:18.760
#  You studied bread.
#
# 23:18.760 --> 23:20.200
#  I kind of did.
#
# 23:20.200 --> 23:22.960
#  I studied the makers of bread,
#
# 23:22.960 --> 23:25.480
#  a little yeast called Saccharomyces cerevisiae,
#
# 23:25.480 --> 23:29.200
#  which at the time was one of the hottest, excuse the pun,
#
# 23:29.200 --> 23:30.920
#  organisms to work on.
#
# 23:30.920 --> 23:35.300
#  But we figured out in the lab why yeast cells get old
#
# 23:35.300 --> 23:37.440
#  and found genes that control that process
#
# 23:37.440 --> 23:39.000
#  and made them live longer,
#
# 23:39.000 --> 23:41.400
#  which was an amazing four years of my life.
#
# 23:41.400 --> 23:46.400
#  One of those genes had a name with an acronym SIR2.
#
# 23:48.200 --> 23:49.680
#  Now the two is irrelevant.
#
# 23:49.680 --> 23:51.800
#  The SIR is important.
#
# 23:51.800 --> 23:53.920
#  And the most important letter out of all of those three
#
# 23:53.920 --> 23:56.960
#  is I, which stands for information.
#
# 23:56.960 --> 23:59.620
#  Silent information regulator number two,
#
# 23:59.620 --> 24:01.080
#  when you put more copies of that gene in,
#
# 24:01.080 --> 24:02.760
#  just put in one more copy,
#
# 24:02.760 --> 24:04.720
#  the yeast cells lived 30% longer
#
# 24:04.720 --> 24:06.080
#  and suppressed the cause of aging,
#
# 24:06.080 --> 24:09.000
#  which was the dysregulation of information in the cell.
#
# 24:09.000 --> 24:11.640
#  And then, so fast forward to now,
#
# 24:11.640 --> 24:14.600
#  I've been looking in humans and mice,
#
# 24:14.600 --> 24:17.760
#  because they live shorter and cheaper to study,
#
# 24:17.760 --> 24:20.780
#  where the loss of information in our bodies
#
# 24:20.780 --> 24:22.580
#  is a root cause of aging.
#
# 24:22.580 --> 24:24.040
#  And I think it is.
#
# 24:24.040 --> 24:29.040
#  Your boldness in doing biology in this way is fascinating
#
# 24:29.520 --> 24:31.840
#  because that also leads to a kind of,
#
# 24:31.840 --> 24:36.840
#  it's almost like allows for a theory of aging,
#
# 24:40.280 --> 24:43.080
#  like you could boil it down to a single equation
#
# 24:43.080 --> 24:45.920
#  and it leads to a, perhaps a metric
#
# 24:45.920 --> 24:48.620
#  that allows you to optimize aging,
#
# 24:48.620 --> 24:51.280
#  sort of in the fight against entropy.
#
# 24:51.280 --> 24:53.820
#  I had to figure out which mechanisms, like you said,
#
# 24:53.820 --> 24:55.680
#  the silent information regulator,
#
# 24:55.680 --> 24:58.560
#  which mechanisms allow you to preserve information
#
# 24:58.560 --> 25:03.560
#  without injecting noise, without creating entropy,
#
# 25:03.760 --> 25:06.120
#  without creating degradation of that information.
#
# 25:07.000 --> 25:11.180
#  For some reason, converting biology,
#
# 25:11.180 --> 25:13.520
#  which I thought was mostly impossible
#
# 25:13.520 --> 25:15.680
#  into an engineering problem,
#
# 25:15.680 --> 25:19.400
#  feels like it makes it amenable to optimization,
#
# 25:19.400 --> 25:23.440
#  to solving problems, to creating technology that can,
#
# 25:23.440 --> 25:26.680
#  whether that's genetic engineering or AI,
#
# 25:26.680 --> 25:30.920
#  it makes it possible to create the technology
#
# 25:30.920 --> 25:35.920
#  that would improve the degradation of information and aging.
#
# 25:36.240 --> 25:38.160
#  Is there more concrete ways you think
#
# 25:38.160 --> 25:41.440
#  about the kind of information you want to preserve?
#
# 25:41.440 --> 25:46.120
#  And also, is there good ideas about regulators
#
# 25:46.120 --> 25:51.120
#  of that information, about ways to prevent the distortion,
#
# 25:52.400 --> 25:54.020
#  the degradation of that information?
#
# 25:54.020 --> 25:56.580
#  Right, so we have silent information regulator genes
#
# 25:56.580 --> 25:57.420
#  in our bodies.
#
# 25:57.420 --> 26:00.360
#  We have seven of them, SIRT1 through seven, they're called.
#
# 26:00.360 --> 26:03.200
#  And we found in mice, one way to slow down
#
# 26:03.200 --> 26:05.900
#  the loss of information is to just give more of these,
#
# 26:06.920 --> 26:08.440
#  to upregulate these genes.
#
# 26:08.440 --> 26:12.000
#  So we made a mouse that has more of this SIRT1 gene,
#
# 26:12.000 --> 26:15.160
#  turned it on, and that slowed down the aging of the brain
#
# 26:15.160 --> 26:16.520
#  and preserved their information.
#
# 26:16.520 --> 26:19.440
#  Now, what information am I talking about, you might ask?
#
# 26:19.440 --> 26:22.000
#  Well, again, you can simplify biology.
#
# 26:22.000 --> 26:25.100
#  There are two types of information in the cell primarily.
#
# 26:25.100 --> 26:27.200
#  The one we all read about and know about
#
# 26:27.200 --> 26:29.040
#  is the DNA, the genome.
#
# 26:29.040 --> 26:32.440
#  And that's base four information, ATCG,
#
# 26:32.440 --> 26:35.240
#  the four chemicals that make up the various sequences
#
# 26:35.240 --> 26:37.000
#  of the genome, billions of letters.
#
# 26:37.880 --> 26:39.960
#  And that also degrades over time.
#
# 26:39.960 --> 26:42.600
#  But what's been fascinating is that we find
#
# 26:42.600 --> 26:45.120
#  that that information is pretty much intact
#
# 26:45.120 --> 26:47.280
#  in old animals and people.
#
# 26:47.280 --> 26:48.240
#  You can clone a dog.
#
# 26:48.240 --> 26:50.980
#  One of my friends in LA just cloned his dog three times.
#
# 26:50.980 --> 26:52.080
#  So this is doable, right?
#
# 26:52.080 --> 26:53.800
#  It means that the genome can be intact.
#
# 26:53.800 --> 26:56.200
#  But what's the other type of information?
#
# 26:56.200 --> 26:58.480
#  It's the epigenome, the regulators
#
# 26:58.480 --> 27:01.220
#  of the genetic information.
#
# 27:01.220 --> 27:04.380
#  And physically, that's really just how the DNA is wrapped up
#
# 27:04.380 --> 27:08.040
#  or looped out for the cell to access it and read it.
#
# 27:08.040 --> 27:11.200
#  So it's similar to, and excuse this analogy,
#
# 27:11.200 --> 27:15.200
#  but it's a good one, a compact disc or a DVD.
#
# 27:15.200 --> 27:18.480
#  Those pits in the foil are the digital information.
#
# 27:18.480 --> 27:19.560
#  That's the genome.
#
# 27:19.560 --> 27:22.240
#  And the epigenome is the reader of that information.
#
# 27:22.240 --> 27:25.320
#  And in a different cell, you'd read different music,
#
# 27:25.320 --> 27:28.000
#  different songs, different symphonies.
#
# 27:28.000 --> 27:31.600
#  And that's what gets laid down when we're in the womb.
#
# 27:31.600 --> 27:34.600
#  And that makes a skin cell forever a skin cell
#
# 27:34.600 --> 27:36.360
#  and not a brain cell tomorrow.
#
# 27:36.360 --> 27:38.760
#  Thank God, otherwise our brains wouldn't work very well.
#
# 27:38.760 --> 27:41.200
#  But over time, what we see is that the brain cells
#
# 27:41.200 --> 27:42.880
#  start to look more like skin cells.
#
# 27:42.880 --> 27:45.620
#  And the kidney cells start to look more like liver cells.
#
# 27:45.620 --> 27:48.120
#  And what we call X differentiate.
#
# 27:48.120 --> 27:49.400
#  This is a term that we use in my lab,
#
# 27:49.400 --> 27:52.080
#  but isn't yet widely used.
#
# 27:52.080 --> 27:53.400
#  But we needed a term to explain this.
#
# 27:53.400 --> 27:55.840
#  And that process of X differentiation,
#
# 27:55.840 --> 28:00.840
#  the loss of the reader of the CD or the DVD,
#
# 28:01.160 --> 28:06.160
#  we liken that to scratches on the DVD
#
# 28:06.200 --> 28:09.440
#  so that the reader cannot fully access the information.
#
# 28:09.440 --> 28:11.440
#  Now we can slow down the scratches, as I mentioned.
#
# 28:11.440 --> 28:13.120
#  We can turn on these genes.
#
# 28:13.120 --> 28:15.880
#  We can even put in molecules into the cell
#
# 28:15.880 --> 28:18.960
#  or even eat them and turn on those pathways,
#
# 28:18.960 --> 28:21.520
#  which my father and I have been trying to do
#
# 28:21.520 --> 28:24.400
#  for about a decade to slow things down.
#
# 28:24.400 --> 28:26.360
#  But the question that I've had is,
#
# 28:27.360 --> 28:30.840
#  is there a repository of information still in the body?
#
# 28:30.840 --> 28:32.240
#  Because anyone who knows anything
#
# 28:32.240 --> 28:33.400
#  about the loss of information
#
# 28:33.400 --> 28:35.520
#  or even has tried to copy a cassette tape
#
# 28:35.520 --> 28:38.720
#  or photocopy or Xerox anything knows that over time,
#
# 28:38.720 --> 28:41.760
#  you lose that information irreparably.
#
# 28:41.760 --> 28:43.940
#  So I've been looking for a backup copy,
#
# 28:43.940 --> 28:46.720
#  inspired largely by Claude Shannon's work
#
# 28:46.720 --> 28:48.780
#  at MIT as well in the 1940s.
#
# 28:48.780 --> 28:53.060
#  His mathematical theory of communication is just brilliant.
#
# 28:53.060 --> 28:55.500
#  And so I've been looking for what he called the observer,
#
# 28:55.500 --> 28:57.200
#  which is the backup copy.
#
# 28:57.200 --> 29:01.500
#  We today might call that the TCPIP protocol of the internet
#
# 29:01.500 --> 29:04.020
#  that stores information in case it doesn't make it
#
# 29:04.020 --> 29:06.900
#  to your computer, it will fill in the gaps.
#
# 29:06.900 --> 29:09.380
#  And we've been spending about the last five years
#
# 29:09.380 --> 29:12.160
#  to try and find if there really is a backup copy in the body
#
# 29:12.160 --> 29:15.960
#  to reset the epigenome and polish those scratches away.
#
# 29:15.960 --> 29:16.940
#  That's incredible.
#
# 29:16.940 --> 29:19.700
#  So finding the backup, so whenever there are too many
#
# 29:19.700 --> 29:24.540
#  scratches pile up, you can just write a new version.
#
# 29:24.540 --> 29:26.540
#  Like write, not a new version,
#
# 29:26.540 --> 29:29.120
#  but go to the backup and restore it.
#
# 29:29.120 --> 29:31.660
#  Right, that's really all we're talking about.
#
# 29:31.660 --> 29:34.420
#  It's not that hard once you know the trick.
#
# 29:34.420 --> 29:38.420
#  And for people that actually remember like DVDs
#
# 29:38.420 --> 29:41.540
#  and scratches on them, how frustrating it is.
#
# 29:41.540 --> 29:44.200
#  That's a brilliant metaphor for aging.
#
# 29:44.200 --> 29:49.200
#  And then the reader is the thing that skips
#
# 29:51.000 --> 29:53.400
#  and then it could destroy your experience,
#
# 29:53.400 --> 29:55.800
#  the richness of the experience that is listening
#
# 29:55.800 --> 29:57.160
#  to your favorite song.
#
# 29:57.160 --> 29:59.000
#  Right, but in biology, it's even worse
#
# 29:59.000 --> 30:01.120
#  because you'll lose your memory, your kidneys will fail,
#
# 30:01.120 --> 30:03.640
#  you'll get diabetes, your heart will fail.
#
# 30:03.640 --> 30:06.880
#  And we call that aging and age related diseases.
#
# 30:06.880 --> 30:10.040
#  So most people forget that diseases that we get
#
# 30:10.040 --> 30:13.860
#  when we get old are 80 to 90% caused by aging.
#
# 30:13.860 --> 30:15.960
#  And we've been trying to fix things with band aids
#
# 30:15.960 --> 30:19.040
#  after they occur without even generally talking
#
# 30:19.040 --> 30:21.360
#  about the root cause of the problem.
#
# 30:21.360 --> 30:26.240
#  Is there the scratches, do those come from,
#
# 30:28.260 --> 30:31.880
#  are those programmed or are they failures?
#
# 30:31.880 --> 30:36.440
#  Meaning is it, so if it's by design,
#
# 30:36.440 --> 30:40.960
#  then there's like a encoded timeline schedule
#
# 30:40.960 --> 30:43.000
#  that the body's just on purpose,
#
# 30:43.000 --> 30:44.560
#  degrading the whole thing.
#
# 30:44.560 --> 30:47.100
#  And then there's the just the wear and tear
#
# 30:47.100 --> 30:50.400
#  of like the scratches on a disc that happen through time.
#
# 30:50.400 --> 30:52.780
#  Which one is it that's the source of aging?
#
# 30:54.240 --> 30:56.940
#  It's more akin to wear and tear, there isn't a program.
#
# 30:56.940 --> 31:00.760
#  Getting back to evolution, there's no selection for aging.
#
# 31:00.760 --> 31:03.600
#  We're not designed to age, we just live as long as we need
#
# 31:03.600 --> 31:06.160
#  to and then we're at the whim of entropy, basically.
#
# 31:06.160 --> 31:09.120
#  Second law of thermodynamics, stuff falls apart.
#
# 31:09.120 --> 31:11.200
#  We live a bit longer than age 40,
#
# 31:11.200 --> 31:13.420
#  only because there are robust, resilient systems,
#
# 31:13.420 --> 31:15.320
#  but eventually they fail as well.
#
# 31:15.320 --> 31:16.940
#  Current limit to the human lifespan
#
# 31:16.940 --> 31:19.280
#  where they completely fail is 122.
#
# 31:21.480 --> 31:23.240
#  But I don't like to think of it as wear and tear
#
# 31:23.240 --> 31:25.880
#  because there's two aspects to it.
#
# 31:25.880 --> 31:28.080
#  There's a system that's built to keep us alive
#
# 31:28.080 --> 31:30.960
#  when we're young, but actually goes,
#
# 31:30.960 --> 31:33.280
#  comes back to bite us as we get older.
#
# 31:33.280 --> 31:37.800
#  And we call this issue antagonistic pleiotropy.
#
# 31:37.800 --> 31:39.500
#  What's good for you when you're young
#
# 31:39.500 --> 31:42.920
#  can cause problems when you're older.
#
# 31:42.920 --> 31:46.160
#  So we've been looking, what is the main causes of the noise?
#
# 31:46.160 --> 31:49.320
#  And we've found two of them definitively.
#
# 31:49.320 --> 31:52.000
#  The first one is broken chromosomes.
#
# 31:52.000 --> 31:55.000
#  When a chromosome breaks, the cell has to panic
#
# 31:55.000 --> 31:58.280
#  because that's either gonna cause a cancer or kill the cell.
#
# 31:58.280 --> 32:01.180
#  There's only two outcomes, it's pretty much a problem.
#
# 32:01.180 --> 32:05.100
# ...
#
# 1:31:12.980 --> 1:31:15.140
#  This experience that we're having here
#
# 1:31:15.140 --> 1:31:18.260
#  is altering certain genes in neurons
#
# 1:31:18.260 --> 1:31:22.060
#  that will be preserved, hopefully, for a number of decades,
#
# 1:31:22.060 --> 1:31:25.300
#  but you cannot see that with a microscope easily,
#
# 1:31:25.300 --> 1:31:27.780
#  but there are technologies invented,
#
# 1:31:27.780 --> 1:31:30.740
#  actually just down the hall in the building I'm at,
#
# 1:31:30.740 --> 1:31:33.520
#  George Church invented a way, his lab invented a way,
#
# 1:31:33.520 --> 1:31:35.980
#  to look at which genes are switched on and off,
#
# 1:31:36.840 --> 1:31:40.100
#  not only in a single cell, which any lab can do these days,
#
# 1:31:40.100 --> 1:31:42.980
#  but in situ, where it's situated in the brain.
#
# 1:31:42.980 --> 1:31:45.240
#  So you can say, okay, this nerve cell,
#
# 1:31:45.240 --> 1:31:47.700
#  had these genes switched on and these switched off,
#
# 1:31:47.700 --> 1:31:49.740
#  we can recreate that,
#
# 1:31:49.740 --> 1:31:50.980
#  but just scanning the brain
#
# 1:31:50.980 --> 1:31:52.540
#  and looking how the nerves are touching each other
#
# 1:31:52.540 --> 1:31:53.540
#  is not gonna do it.
#
# 1:31:54.820 --> 1:31:55.900
#  Wow, okay.
#
# 1:31:55.900 --> 1:31:59.260
#  So you have to scan the full biology, the full details.
#
# 1:31:59.260 --> 1:32:00.420
#  And look at the epigenome.
#
# 1:32:00.420 --> 1:32:01.580
#  And the epigenome too.
#
# 1:32:01.580 --> 1:32:03.140
#  Yeah, which genes are on and off.
#
# 1:32:03.140 --> 1:32:05.080
#  It's just easier to reset the epigenome
#
# 1:32:05.080 --> 1:32:06.500
#  and get them to work like they used to.
#
# 1:32:06.500 --> 1:32:07.540
#  True, true.
#
# 1:32:07.540 --> 1:32:08.380
#  We're doing that now.
#
# 1:32:08.380 --> 1:32:09.760
#  Use the hardware we already have,
#
# 1:32:09.760 --> 1:32:13.860
#  just figure out how to make that hardware last longer.
#
# 1:32:13.860 --> 1:32:15.700
#  Right, ultimately information will be lost,
#
# 1:32:15.700 --> 1:32:19.380
#  even genetic information degrades slowly through mutation.
#
# 1:32:19.380 --> 1:32:22.540
#  So immortality is not achievable through that means,
#
# 1:32:22.540 --> 1:32:25.280
#  though I think we could potentially reset the body
#
# 1:32:25.280 --> 1:32:28.480
#  hundreds of times and live for thousands of years.
#
# 1:32:28.480 --> 1:32:31.540
#  Okay, so we talked about biology.
#
# 1:32:31.540 --> 1:32:34.620
#  Let's, forgive me, but let's talk about philosophy
#
# 1:32:34.620 --> 1:32:36.740
#  for just a brief moment.
#
# 1:32:36.740 --> 1:32:38.740
#  So somebody I've enjoyed reading,
#
# 1:32:38.740 --> 1:32:40.700
#  Ernest Becker wrote The Denial of Death.
#
# 1:32:40.700 --> 1:32:42.980
#  There's also Martin Heidegger.
#
# 1:32:42.980 --> 1:32:47.820
#  There's a bunch of philosophers who claim
#
# 1:32:47.820 --> 1:32:51.980
#  that most people live life in denial of death.
#
# 1:32:51.980 --> 1:32:56.980
#  Sort of we don't fully internalize
#
# 1:32:58.400 --> 1:33:00.140
#  the idea that we're going to die.
#
# 1:33:04.220 --> 1:33:07.000
#  Because if we did, as they say,
#
# 1:33:07.000 --> 1:33:10.260
#  there will be a kind of terror of,
#
# 1:33:11.220 --> 1:33:14.120
#  I mean a deep fear of death.
#
# 1:33:15.380 --> 1:33:17.280
#  The fact that we don't know what's,
#
# 1:33:17.280 --> 1:33:22.280
#  like we almost don't know what to do with non existence,
#
# 1:33:23.260 --> 1:33:24.860
#  with disappearing.
#
# 1:33:24.860 --> 1:33:28.300
#  Like our, the way we draw meaning from life
#
# 1:33:28.300 --> 1:33:30.860
#  seems to be grounded in the fact that we exist
#
# 1:33:30.860 --> 1:33:34.620
#  and that we at some point will not exist is terrifying.
#
# 1:33:34.620 --> 1:33:37.660
#  And so we live in an illusion that we're not going to die
#
# 1:33:37.660 --> 1:33:39.700
#  and we run from that terror.
#
# 1:33:39.700 --> 1:33:41.740
#  That's what Ernest Becker would say.
#
# 1:33:41.740 --> 1:33:44.260
#  Do you think there's any truth to that?
#
# 1:33:44.260 --> 1:33:45.460
#  Oh, I know there's truth to that.
#
# 1:33:45.460 --> 1:33:47.820
#  I experience it every day when I talk to people.
#
# 1:33:47.820 --> 1:33:49.700
#  We have to live that way.
#
# 1:33:49.700 --> 1:33:51.420
#  Although unfortunately I can't,
#
# 1:33:51.420 --> 1:33:56.420
#  but for most people it's extremely distressing
#
# 1:33:56.540 --> 1:33:59.380
#  to think about their own mortality.
#
# 1:33:59.380 --> 1:34:00.580
#  We think about it occasionally.
#
# 1:34:00.580 --> 1:34:02.300
#  And if we really thought about it every day,
#
# 1:34:02.300 --> 1:34:04.020
#  we'd probably be brought to tears.
#
# 1:34:04.020 --> 1:34:05.780
#  How much we not just miss ourselves,
#
# 1:34:05.780 --> 1:34:07.580
#  but miss our family, our friends.
#
# 1:34:10.140 --> 1:34:14.420
#  All living life forms have evolved to not want to die.
#
# 1:34:14.420 --> 1:34:15.680
#  And when I mean want,
#
# 1:34:15.680 --> 1:34:18.220
#  biochemically, genetically, physically.
#
# 1:34:18.220 --> 1:34:21.660
#  That yeast cell, the cells that I studied at MIT,
#
# 1:34:21.660 --> 1:34:23.700
#  they were fighting for their lives.
#
# 1:34:23.700 --> 1:34:25.260
#  They didn't think,
#
# 1:34:25.260 --> 1:34:28.980
#  but our brain has evolved the same survival aspect.
#
# 1:34:28.980 --> 1:34:30.380
#  Of course, we don't want to die.
#
# 1:34:30.380 --> 1:34:32.540
#  But the problem for us, unfortunately,
#
# 1:34:32.540 --> 1:34:34.960
#  it's a curse and a blessing is that we're now conscious.
#
# 1:34:34.960 --> 1:34:37.180
#  We know that we're going to die.
#
# 1:34:37.180 --> 1:34:40.300
#  Most species that have ever existed don't.
#
# 1:34:40.300 --> 1:34:42.300
#  That's a burden, that's a curse.
#
# 1:34:42.300 --> 1:34:43.660
#  And so what I think has happened is
#
# 1:34:43.660 --> 1:34:46.900
#  we've evolved certainly to want to live for a long time,
#
# 1:34:46.900 --> 1:34:49.140
#  perhaps never want to die.
#
# 1:34:49.140 --> 1:34:52.160
#  But the thought about dying is so traumatic
#
# 1:34:52.160 --> 1:34:55.620
#  that there is an innate part of our brains.
#
# 1:34:55.620 --> 1:34:59.260
#  And it's probably genetically wired to not think about it.
#
# 1:35:00.940 --> 1:35:03.180
#  I really think that's part of being human.
#
# 1:35:03.180 --> 1:35:06.020
#  Because, think about tribes that obsessed
#
# 1:35:06.020 --> 1:35:09.620
#  with longevity every day and that we're going to die.
#
# 1:35:09.620 --> 1:35:12.300
#  They probably didn't make much technological progress
#
# 1:35:12.300 --> 1:35:14.540
#  because they were just crying in their huts every day
#
# 1:35:14.540 --> 1:35:16.220
#  or on the Savannah.
#
# 1:35:16.220 --> 1:35:18.060
#  So I really think that we've evolved
#
# 1:35:18.060 --> 1:35:20.340
#  to naturally deny aging.
#
# 1:35:20.340 --> 1:35:23.180
#  And it's one of the problems that I face in my career.
#
# 1:35:23.180 --> 1:35:26.780
#  And when I speak publicly and on social media
#
# 1:35:26.780 --> 1:35:28.340
#  is that it's shocking.
#
# 1:35:28.340 --> 1:35:29.920
#  People don't want to think about their age,
#
# 1:35:29.920 --> 1:35:31.720
#  but I think it's getting better.
#
# 1:35:31.720 --> 1:35:33.940
#  I think my book has helped.
#
# 1:35:33.940 --> 1:35:35.220
#  These tests that we're developing
#
# 1:35:35.220 --> 1:35:38.340
#  should help people understand it's not a problem
#
# 1:35:38.340 --> 1:35:40.300
#  to think about your longterm health.
#
# 1:35:40.300 --> 1:35:41.820
#  In fact, if you don't,
#
# 1:35:41.820 --> 1:35:44.060
#  you're going to reach 80 and really regret it.
#
# 1:35:45.260 --> 1:35:47.740
#  And the other side of it, so again, Ernest Becker,
#
# 1:35:47.740 --> 1:35:50.140
#  but also Viktor Frankl recommended highly
#
# 1:35:50.140 --> 1:35:51.340
#  Man's Search for Meaning.
#
# 1:35:52.300 --> 1:35:54.900
#  Bernard Williams is a moral philosopher.
#
# 1:35:54.900 --> 1:35:58.620
#  They kind of argue that this knowledge of death,
#
# 1:35:58.620 --> 1:36:03.620
#  even if we often don't contemplate it, we do at times.
#
# 1:36:03.840 --> 1:36:06.960
#  And the very, what you call the curse,
#
# 1:36:06.960 --> 1:36:10.620
#  which I agree with you, it's a curse and a blessing
#
# 1:36:10.620 --> 1:36:13.900
#  that we're able to contemplate our own mortality.
#
# 1:36:13.900 --> 1:36:16.580
#  That gives meaning to life.
#
# 1:36:16.580 --> 1:36:18.860
#  So death gives meaning to life,
#
# 1:36:18.860 --> 1:36:21.140
#  is what Viktor Frankl argues.
#
# 1:36:21.140 --> 1:36:22.600
#  I would probably argue the same.
#
# 1:36:22.600 --> 1:36:25.180
#  There's something about the scarcity of life
#
# 1:36:25.180 --> 1:36:27.140
#  and contemplating that,
#
# 1:36:27.140 --> 1:36:30.180
#  that makes each moment that much sweeter.
#
# 1:36:30.180 --> 1:36:32.380
#  Is there something to that?
#
# 1:36:32.380 --> 1:36:33.860
#  I think it's individual.
#
# 1:36:33.860 --> 1:36:35.980
#  In my case, it's completely wrong.
#
# 1:36:35.980 --> 1:36:39.820
#  I appreciate you saying that.
#
# 1:36:39.820 --> 1:36:41.860
#  I don't get joy out of every day
#
# 1:36:41.860 --> 1:36:43.780
#  because I think I'm going to die.
#
# 1:36:43.780 --> 1:36:46.060
#  I get joy out of every day because every day is joyous
#
# 1:36:46.060 --> 1:36:47.460
#  and I make it that way.
#
# 1:36:47.460 --> 1:36:50.460
#  And even if I thought I was going to live forever,
#
# 1:36:50.460 --> 1:36:53.140
#  I would still be enjoying this moment just as much.
#
# 1:36:54.580 --> 1:36:56.340
#  And I bet you would too.
#
# 1:36:56.340 --> 1:36:59.900
#  Well, I think about that a lot.
#
# 1:36:59.900 --> 1:37:03.580
#  I think it's very difficult to know.
#
# 1:37:03.580 --> 1:37:06.740
#  I'm almost afraid that I wouldn't enjoy it as much
#
# 1:37:06.740 --> 1:37:07.980
#  if I was immortal.
#
# 1:37:07.980 --> 1:37:11.900
#  I'm almost afraid to want to be immortal or to live longer
#
# 1:37:11.900 --> 1:37:16.900
#  because it perhaps is a kind of justification
#
# 1:37:18.460 --> 1:37:21.700
#  for me to accept that I'm going to die.
#
# 1:37:21.700 --> 1:37:23.420
#  It's saying like, oh, if I was immortal,
#
# 1:37:23.420 --> 1:37:26.160
#  I wouldn't be able to enjoy life as much as I do.
#
# 1:37:26.160 --> 1:37:29.240
#  But it's very possible that I would enjoy just as much.
#
# 1:37:30.260 --> 1:37:34.220
#  Of course, enjoying life, whether you're immortal or not,
#
# 1:37:34.220 --> 1:37:35.540
#  takes work.
#
# 1:37:35.540 --> 1:37:38.580
#  Like it requires you to have the right kind
#
# 1:37:38.580 --> 1:37:39.820
#  of frame of mind.
#
# 1:37:39.820 --> 1:37:42.460
#  You can discover, you can focus your mind
#
# 1:37:42.460 --> 1:37:44.500
#  on the ugliness of life.
#
# 1:37:44.500 --> 1:37:46.900
#  There's plenty of ugly things in this world
#
# 1:37:46.900 --> 1:37:47.960
#  and you can focus on them.
#
# 1:37:47.960 --> 1:37:49.340
#  You can complain.
#
# 1:37:49.340 --> 1:37:53.460
#  Whenever like, you know, if it's raining outside,
#
# 1:37:53.460 --> 1:37:56.740
#  you can focus on the fact that you have shelter
#
# 1:37:56.740 --> 1:37:58.460
#  and enjoy the hell out of it.
#
# 1:37:58.460 --> 1:38:02.020
#  Or you can enjoy running in the rain when it's warm
#
# 1:38:02.020 --> 1:38:05.700
#  and the beauty of nature, just being one with nature.
#
# 1:38:05.700 --> 1:38:07.920
#  Or you can just complain, it's fucking weather again
#
# 1:38:07.920 --> 1:38:10.420
#  in Boston and then it's either always raining
#
# 1:38:10.420 --> 1:38:11.920
#  or freezing, damn it.
#
# 1:38:13.920 --> 1:38:18.340
#  The same thing with like wifi going out on airplanes.
#
# 1:38:18.340 --> 1:38:23.340
#  You can either complain about stupid wifi
#
# 1:38:23.340 --> 1:38:25.860
#  on JetBlue or something.
#
# 1:38:25.860 --> 1:38:27.620
#  Or you could say like, how incredible it is
#
# 1:38:27.620 --> 1:38:30.180
#  that I can fly through the sky and in a matter of hours
#
# 1:38:30.180 --> 1:38:31.700
#  be anywhere else in the world.
#
# 1:38:31.700 --> 1:38:35.700
#  And then I could also on occasion watch like check email
#
# 1:38:35.700 --> 1:38:39.540
#  and even watch movies while connecting through satellites
#
# 1:38:39.540 --> 1:38:40.500
#  that are flying through space.
#
# 1:38:40.500 --> 1:38:42.780
#  So it's a matter of perspective and perhaps
#
# 1:38:42.780 --> 1:38:44.980
#  there's an extra level of work required
#
# 1:38:44.980 --> 1:38:47.620
#  when you're immortal because it's easier
#
# 1:38:47.620 --> 1:38:51.680
#  when you're immortal or live longer to be lazy,
#
# 1:38:51.680 --> 1:38:52.980
#  to delay stuff.
#
# 1:38:52.980 --> 1:38:55.020
#  But if you're not, you can still derive
#
# 1:38:55.020 --> 1:38:56.460
#  the same amount of joy.
#
# 1:38:56.460 --> 1:38:59.060
#  It's possible, it's possible.
#
# 1:38:59.060 --> 1:38:59.900
#  It's definitely possible.
#
# 1:38:59.900 --> 1:39:03.120
#  In my life, I went from being the nothing's working
#
# 1:39:03.120 --> 1:39:06.660
#  to every day's great to wake up to.
#
# 1:39:06.660 --> 1:39:10.460
#  And I think even if you think you can live forever,
#
# 1:39:10.460 --> 1:39:12.180
#  you can enjoy every day.
#
# 1:39:12.180 --> 1:39:14.040
#  What I do is everything's relative.
#
# 1:39:14.940 --> 1:39:17.900
#  We can compare ourselves to our neighbor who has more money
#
# 1:39:17.900 --> 1:39:20.460
#  or to the flight that should have had wifi
#
# 1:39:20.460 --> 1:39:23.580
#  or which is what I do, I'm still six years old remember.
#
# 1:39:23.580 --> 1:39:27.780
#  What a six year old does says, look, I can,
#
# 1:39:27.780 --> 1:39:29.940
#  when I tell my fingers to form a fist,
#
# 1:39:29.940 --> 1:39:31.300
#  they actually do that.
#
# 1:39:31.300 --> 1:39:32.700
#  That's really cool.
#
# 1:39:32.700 --> 1:39:34.740
#  That's how I live my life.
#
# 1:39:34.740 --> 1:39:36.840
#  I can pick up on your desk here, this metal object.
#
# 1:39:36.840 --> 1:39:39.860
#  It's a metal cube, about an inch by an inch by an inch.
#
# 1:39:39.860 --> 1:39:42.560
#  And I tell myself not about cubes,
#
# 1:39:42.560 --> 1:39:44.920
#  but about inanimate objects.
#
# 1:39:44.920 --> 1:39:48.260
#  Probably once a day I'll say, I'm a living thing.
#
# 1:39:48.260 --> 1:39:51.880
#  I can think, I can move, I can eat, I am full of energy.
#
# 1:39:51.880 --> 1:39:53.920
#  And there's that leaf or this cube here
#
# 1:39:53.920 --> 1:39:55.840
#  that will never be alive.
#
# 1:39:55.840 --> 1:39:59.180
#  That's what I look at and compare myself to.
#
# 1:39:59.180 --> 1:40:01.100
#  And for as long as I live, if it's forever,
#
# 1:40:01.100 --> 1:40:04.500
#  of course it won't be, but even if it was forever,
#
# 1:40:04.500 --> 1:40:07.780
#  relative to this lump of metal on this table here,
#
# 1:40:07.780 --> 1:40:10.860
#  we are wondrous things in the universe
#
# 1:40:10.860 --> 1:40:13.740
#  and probably the most wondrous things in the universe.
#
# 1:40:13.740 --> 1:40:18.660
#  Yeah, we're able to deeply appreciate the leaf or the cube
#
# 1:40:18.660 --> 1:40:20.540
#  and deeply appreciate ourselves,
#
# 1:40:20.540 --> 1:40:24.400
#  which is, it can be a curse, but it's mostly a gift,
#
# 1:40:24.400 --> 1:40:28.140
#  especially when you're, it's such a beautiful poem.
#
# 1:40:29.040 --> 1:40:31.640
#  Now I'm six, I'm as clever as clever,
#
# 1:40:31.640 --> 1:40:35.380
#  so I think I'll be six now forever and ever.
#
# 1:40:35.380 --> 1:40:37.840
#  That's a good thing to aspire to.
#
# 1:40:37.840 --> 1:40:40.600
#  Your grandmother was onto something.
#
# 1:40:40.600 --> 1:40:43.000
#  David, this is an incredible conversation.
#
# 1:40:43.000 --> 1:40:44.620
#  I'm a huge fan of your work.
#
# 1:40:44.620 --> 1:40:49.320
#  So thank you for wasting your valuable time with me today.
#
# 1:40:49.320 --> 1:40:50.480
#  I really, really appreciate it.
#
# 1:40:50.480 --> 1:40:51.320
#  This was awesome.
#
# 1:40:51.320 --> 1:40:53.960
#  Thank you for having me on, Lex, appreciate it.
#
# 1:40:53.960 --> 1:40:55.480
#  Thanks for listening to this conversation
#
# 1:40:55.480 --> 1:40:59.720
#  with David Sinclair, and thank you to Onnit, Clear,
#
# 1:40:59.720 --> 1:41:03.600
#  National Instruments, Simply Safe, and Linode.
#
# 1:41:03.600 --> 1:41:07.100
#  Check them out in the description to support this podcast.
#
# 1:41:07.100 --> 1:41:08.680
#  And now let me leave you with some words
#
# 1:41:08.680 --> 1:41:10.600
#  from Arthur Schopenhauer.
#
# 1:41:10.600 --> 1:41:13.660
#  All truth passes through three stages.
#
# 1:41:13.660 --> 1:41:15.460
#  First, it is ridiculed.
#
# 1:41:15.460 --> 1:41:18.200
#  Second, it is violently opposed.
#
# 1:41:18.200 --> 1:41:22.240
#  Third, it is accepted as being self evident.
#
# 1:41:22.240 --> 1:41:26.400
#  Thank you for listening, and hope to see you next time.

# %%
def remove_timestamps_vtt(file_path):
    with open(file_path, 'r') as file:
      content = file.read()

    # Remove "WEBVTT" header
    content = content.replace("WEBVTT", "").strip()
    
    # Remove timestamps
    cleaned_content = re.sub(r'(\d{1,2}:)?\d{1,2}:\d{2}\.\d{3} --> (\d{1,2}:)?\d{1,2}:\d{2}\.\d{3}', '', content)

    # Remove extra newline characters
    cleaned_content = re.sub(r'\n{2,}', '\n', cleaned_content)

    # Replace newline characters with spaces
    cleaned_content = cleaned_content.replace('\n', ' ')

    # Remove extra whitespaces
    cleaned_content = re.sub(r'\s+', ' ', cleaned_content)

    return cleaned_content

# %%
cleaned_content = remove_timestamps_vtt(file_path)
cleaned_content
# Out:
# " The following is a conversation with David Sinclair. He's a professor in the Department of Genetics at Harvard and co director of the Paul F. Glenn Center for the Biology of Aging at Harvard Medical School. He's the author of the book, Lifespan and co founder of several biotech companies. He works on turning age into an engineering problem and solving it. Driven by a vision of a world where billions of people can live much longer and much healthier lives. Quick mention of our sponsors, Onnit, Clear, National Instruments, and I, SimpliSafe and Linode. Check them out in the description to support this podcast. As a side note, let me say that longevity research challenges us to think how science and engineering will change society. Imagine if we can live 100,000 years, even under controlled conditions, like in a spaceship say, then suddenly a trip to Alpha Centauri that is a 4.37 light years away takes a single human lifespan. And on the psychological, maybe even philosophical level, as the horizons of death drifts farther into the distance, how will our search for meaning change? Does meaning require death or does it merely require struggle? Reprogramming our biology will require us to delve deeper into understanding the human mind and the robot mind. Both of these efforts are as exciting of a journey as I can imagine. This is the Lex Friedman Podcast and here is my conversation with David Sinclair. I usually feel like the same person when I was 12. Like when I, right now, as I think about myself, I feel like exactly the same person that I was when I was 12. And yet, I am getting older, both body and mind, and still feel like time hasn't passed at all. Do you feel this tension in yourself that you're the same person and yet you're aging? Yeah, I have this tension that I'm still a kid, but that helps in my career. Scientists need to have a wonder about the world and you don't wanna grow up at 12 year olds and even younger, I would say six, seven year olds. I've still got that boy in me and I can look at things. It's a gift, I think, that I can see things for the first time if I choose to, and then explain them as I would to a six year old because I am that mentally. But on the other hand, I'm getting older, right? I run a lab of 20 people at Harvard. I've got a book, I've got science to do, companies to run, and so I have to, on most days, just pretend to be a grownup and be mature, but I definitely don't feel that way. There's something I really appreciated in opening your book. You talked about your grandmother. And on this kind of theme, on this kind of topic, she, first of all, had a big influence on you. My grandmother had a big influence on me. And you also mentioned this poem by the author of Winnie the Pooh, Alan Alexander Milne. Maybe I can read it real quick because I love, on the topic of being children, when I was one, I had just begun. When I was two, I was nearly new. When I was three, I was hardly me. When I was four, I was not much more. When I was five, I was just alive, but now I am six. I am as clever, as clever, so I think I'll be six, now, forever and ever. So this idea of being six and staying six forever, being youthful, being curious, being childlike, this and other things, what influence has your grandmother had in your thinking about life, about death, about love? Yeah, I was getting misty eyed as you read that because that poem was read to me very often, if not every day, by my grandmother, who partially raised me. And she was as much a bohemian as an artist, philosopher. And she's one of those people that wouldn't talk about the little things. She said, I hate small talk. Don't talk to me about politics or the weather. Yeah, talk to me about human beings and culture. So I was raised on that, and this poem was one that she read to me often because she knew that the mind of a child is precious, it's honest, it's pure. And she grew up during the Second World War and in Hungary and Budapest witnessed the ...

# %%
# number of characters
len(cleaned_content)
# Out:
# 17456

# %%
# split by word
len(cleaned_content.split())
# Out:
# 17456

# %%
# split by sentence
len(re.split(r'[.!?]+', cleaned_content))
# Out:
# 1188

# %%
# split into chunks so that we could summarize each chunk
def split_text(text, max_length):
    tokens = tokenizer.encode(text)
    num_chunks = (len(tokens) + max_length - 1) // max_length
    chunks = []

    for i in range(num_chunks):
        start = i * max_length
        end = (i + 1) * max_length
        chunk_tokens = tokens[start:end]
        chunk_text = tokenizer.decode(chunk_tokens)
        chunks.append(chunk_text)
    
    return chunks

max_length = 1024
chunks = split_text(cleaned_content, max_length)

# %%
len(chunks)
# Out:
# 21

# %%
pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 38.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 69.1 MB/s eta 0:00:00

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

model_name = 'facebook/bart-large-cnn'
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
def summarize(text, tokenizer, model):
    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs, max_length=150, min_length=100, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# %%
# Summarize the text
summary = summarize(chunks[0], tokenizer, model)
print(summary)
# Out:
# David Sinclair is a professor in the Department of Genetics at Harvard Medical School. He's the author of the book, Lifespan and co founder of several biotech companies. Sinclair: I usually feel like the same person when I was 12. I've still got that boy in me and I can look at things as I would a six-year-old. I have to, on most days, just pretend to be a grownup and be mature, but I definitely don't feel that way.

# %%
summarized_chunks = []
for chunk in chunks:
    inputs = tokenizer(chunk, return_tensors='pt', max_length=max_length, truncation=True, padding='max_length')
    summary_ids = model.generate(inputs['input_ids'], num_beams=4, max_length=150, min_length=100, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    summarized_chunks.append(summary)

summarized_text = ' '.join(summarized_chunks)

# %%
summarized_chunks
# Out:
# ['David Sinclair is a professor in the Department of Genetics at Harvard Medical School. He\'s the author of the book, Lifespan and co founder of several biotech companies. He works on turning age into an engineering problem and solving it. Sinclair: "I usually feel like the same person when I was 12. Like when I, right now, as I think about myself, I feel like exactly the sameperson that I was when I were 12" "I\'ve still got that boy in me and I can look at things," he says.',
#  'The writer-director has been working on a project about bringing people back to life through artificial intelligence. He says he\'d like to bring back people that mean something to us personally, not just Einstein, but people that we\'ve lost and in that way achieve a kind of small artificial immortality. "I wouldn\'t go back in time. I would, but I\'d prefer to bring him into the future and say, can you believe we have this thinking machine in our pockets now?" he says.',
#  "David Perry: I'm a biologist. I find animals and humans as machines very interesting. And so I think a lot about machines merging with humans. And the first of that are the bio wearables. Perry: In the very near future, just in the next few years, you can be wearing wearables to monitor your health. He says doctors are already using them to get patients to go home and save a week in hospital, at least $2,000 at least for each patient.",
#  ", certainly in developed countries, eventually these will cost a few cents and rechargeable. The only cost will be the software subscription that can be monitored constantly. We've got sneezing, coughing, body temperature, heart rate, heart of other parameters of the heart that would indicate heart health. These data are being used to now to predict sickness. Eventually we'll have just in the next year or so the ability to predict whether something or diagnose whether something is pneumonia or just a rhinovirus. This is really going to revolutionize medicine, but I think extend lives dramatically.",
#  "Theory of aging came out of discoveries in yeast cells, where he went to MIT in the 1990s. He studied the makers of bread, a little yeast called Saccharomyces cerevisiae, which at the time was one of the hottest, excuse the pun, organisms to work on. He found genes that control that process and made them live longer, which was an amazing four years of my life. And then I've been looking in humans and mice to study where the loss of information in our bodies is a root of aging.",
#  "In mice, one way to slow down the loss of information is to just give more of these genes. We made a mouse that has more of this SIRT1 gene, turned it on, and that slowed down the aging of the brain and preserved their information. We've been spending about the last five years to try and find if there really is a backup copy in the body to reset the epigenome and polish scratches away. Like the TCPIP protocol of the internet that stores information in case it doesn't make it to your computer, it will fill in the gaps.",
#  "We're not designed to age, we just live as long as we need to and then we're at the whim of entropy, basically. We live a bit longer than age 40, only because there are robust, resilient systems, but eventually they fail as well. The first one is broken chromosomes. When a chromosome breaks, the cell has to panic because that's either gonna cause a cancer or kill the cell. And we've also, the other cause of aging that we found is cell stress, we damage nerves and they age rapidly. We have in our bodies close to a trillion DNA breaks every day.",
#  " AI can replicate the aging process in a controlled way. We're using it to predict the folding of proteins so we can target molecules and modulate their activity. The other thing we use it for is to predict a mouse's lifespan based on how it reacts to certain things, generally frailty, generally hearing, sight. We use it to generate these biological clocks to be able to read those biological clocks. And we're going into human studies in less than two years from now. We just published this in the December 2020 issue of Nature. We found a reset switch recently.",
#  "The amount of data that we generate now as biologists is just terabytes. Ultimately, we're going to, even if we don't want to, have to be monitored. There's gonna be a court case that, I bet two, three years from now, someone's gonna say, how come my father died from a heart attack? You had these biosensors, 20 bucks, and you didn't use it. Lawsuit right there, and suddenly, all hospitals have to give you one of these.",
#  '"I think doctors sometimes have a bit of an ego," he says. "There\'s an aspect to it where the doctor has to put their expert hat, like take it off and actually be a curious, open minded person and study and look at that data" "I hope we do create kind of systems where I can volunteer to share my data and I can also take the data back, meaning like delete the data, request deletion of data," he adds. "I feel like if I have the option to delete all my data that a particular company has, then I\'ll share myData with everyone"',
#  'Fasting is one of the oldest ways to improve health, says Dr. Richard Quest. Quest: "You start to see your body\'s almost as a machine that takes food and produces thoughts" Quest: If there was one thing I would recommend to anybody to slow down aging would be to skip a meal or two a day. "I have my physique back that I had when I was 20. I feel 20 mentally. I don\'t feel tired anymore. I sleep well," Quest says.',
#  '"I would like to cheat, I guess, by eating more meat than I, you know, like overeating on the things that I know my body feels good on," Rogan says. "I tend to find happiness in overeating the good stuff versus eating the bad stuff," he adds. "What\'s a long life if it\'s not enjoyable anyway?" Rogan asks. "It\'s a balance that you have to strike," he says. \'I will eat occasional, very occasionally a dessert. Usually I steal from others\'',
#  "In animals we know that there's a mechanism that's called mTOR, little m, capital TOR, that responds to certain amino acids that are found in more abundance in meat. And when it responds, it actually shortens lifespan. And the converse, if you starve it of those three amino acids, mostly in meat, then it extends lifespan. But getting to the bottom of this, what I think is going on is that just like testosterone and growth hormone, you will get temporary, maybe not temporary, immediate health benefits. But the problem is I think it's at the expense of longterm health and longevity.",
#  'CNN\'s John Sutter talks about the benefits of exercise and fasting. He also talks about his love of brown noise. Sutter: "You have to keep a lot of things in mind so you\'re constantly designing things in concrete by making those things in those concrete things in a very precise way. You have quite a different mind, you have a quite a beautiful mind, and you have to explore it" Click here for more from Sutter\'s book, "The Power of One," out now.',
#  '"I would guess based on the evidence that it\'s really important and because we don\'t know for sure" "If you restrict sleep from a rat for just two weeks, it\'ll develop type two diabetes. So that\'s the main thing. What we also know is at the molecular level that if you disrupt your sleep wake cycle, you\'ll get premature aging" "As long as I have a stupid private, usually smile on my face, that\'s when I\'m doing good, as opposed to getting a perfect amount of sleep according to whatever the latest blog post is"',
#  "It's the quality, not the quantity, right? And when you get it. So that, like you say, if you're happy and contented and you don't have these cortisol chemicals going through your body, you will more naturally get into that deep state. And even if you just get four hours, way better than eight hours of none of that. So you've got to work on your brain first and foremost. If you are totally freaked out, agitated all the time, you'll live shorter. I'm certain of it. That's no true surprise.",
#  "The future of data collection look like for the human biological system. You'll get a kit in the mail, you'll swab your cheeks, stick it back in an envelope, send it off and a week later you have either a doctor's report or a health recommendation. And what can you get off a cheek swab? Well, you can get hormones, stress levels, stress hormones, blood glucose levels. You can also tell your age reasonably accurately doing that, actually quite accurately.",
#  "If you do the right things in your life, which is eat healthy food, don't overeat and don't become obese, that gives you on average 14 extra years. I think that we should all aim to at least reach a century. I was born too early to benefit the most from all of this discovery. Those of you who are in your 20s, you should definitely aim to reach a hundred. How long can we ultimately live? Well, there's no maximum limit to human lifespan. There's nothing that I've seen that says biological organisms have to die.",
#  "We're already replacing body parts but what makes us human is our brain. The ability to replace actual neurons is really hard. I'd rather go in and rejuvenate the brain as it sits rather than replace individual cells. Ultimately, I think the best way to preserve the brain is going to be to record it. We're not close, yes, but we've made quite a bit of progress, so if you're an exponential type of person. Yeah, well, let's dream a little here.",
#  "We live in an illusion that we're not going to die and we run from that terror. All living life forms have evolved to not want to die. The thought about dying is so traumatic that there is an innate part of our brains. And it's probably genetically wired to not think about it. So death gives meaning to life, is what Viktor Frankl argues. There's something about the scarcity of life and contemplating that, that makes each moment that much sweeter. And even if I thought I was going to live forever, I would still be enjoying this moment just as much.",
#  'David Sinclair: Even if you think you can live forever, you can enjoy every day. Sinclair: Everything\'s relative. We can compare ourselves to our neighbor who has more money or to the flight that should have had wifi. He says we are wondrous things in the universe and probably the most wondrousThings in the. universe. "It\'s such a beautiful poem. Now I\'m six, I\'m as clever as clever, so I think I\'ll be six now forever and ever," Sinclair says.']
